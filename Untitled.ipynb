# %%
import numpy as np
import cv2
cap1 = cv2.VideoCapture(0)
#cap2 = cv2.VideoCapture(2)
cap3 = cv2.VideoCapture(1)
#cap4 = cv2.VideoCapture(4)
while(True):
    ret1, frame1 = cap1.read()
    #ret2, frame2 = cap2.read()
    ret3, frame3 = cap3.read()
    #ret4, frame4 = cap4.read()
    input_image = np.ones((300,300,3), dtype=np.uint8)
    res1 = cv2.resize(frame1,(300,100),interpolation=cv2.INTER_CUBIC)
    #res2 = cv2.resize(frame2,(300,100),interpolation=cv2.INTER_CUBIC)
    res3 = cv2.resize(frame3,(300,100),interpolation=cv2.INTER_CUBIC)
    input_image[0:100,0:300] = res1[0:100,0:300]
    #input_image[100:200,0:300] = res2[0:100,0:300]
    input_image[200:300,0:300] = res3[0:100,0:300]
    #gray1 = cv2.cvtColor(frame1, cv2.COLOR_BGR2GRAY)
    #gray2 = cv2.cvtColor(frame2, cv2.COLOR_BGR2GRAY)
    gray3 = cv2.cvtColor(frame3, cv2.COLOR_BGR2GRAY)
    cv2.imshow('jingyangxiaojidaigong',input_image)
    #cv2.imshow('jingyangxiaojidaqq',frame4)
    if cv2.waitKey(1) & 0xFF == ord('q'): 
        break
cap1.release()
#cap2.release()
cap3.release()
#cap4.release()
cv2.destroyAllWindows()

# %%
from wordcloud import WordCloud
import PIL.Image as image

fp=open("love.txt")
text = fp.read()
print(text)
wordcloud = WordCloud().generate(text)
image_produce = wordcloud.to_image()
image_produce.show()
# Out:
# 我爱你

# %%
from wordcloud import WordCloud
import PIL.Image as image
import numpy as np
 
with open("love.txt") as fp:
    text = fp.read()
    print(text)
    mask = np.array(image.open("love.png"))
    wordcloud = WordCloud(mask=mask).generate(text)
    image_produce = wordcloud.to_image()
    image_produce.show()
    image_produce.save("myclould.png")
# Out:
# Love
# I love you not because of who you are,but because of who I am when I am with you.
# No man or woman is worth your tears,and the one who is ,won’t make you cry.
# The worst way to miss someone is to be sitting right beside them knowing you can’t have them.
# Never frown,even when you are sad,because you never know who is falling in love with your smile.
# To the world you may be one person,but to one person you may be the world.
# Don’t waste your time on a man/woman,who isn’t willing to waste their time on you.
# Just because someone doesn’t love you the way you want them to,doesn’t mean they don’t love you with all they have.
# Don’t try to hard,the best things come when you least expect them to.

# %%
from wordcloud import WordCloud
import PIL.Image as image

fp=open("love.txt")
text = fp.read()
print(text)
wordcloud = WordCloud(font_path = "C:\Windows\Fonts\simhei.ttf").generate(text)
image_produce = wordcloud.to_image()
image_produce.show()
# Out:
# 康桥国际学校

# %%
from wordcloud import WordCloud
import jieba

fp=open("lovecn.txt")
text = fp.read()
print(text)
wordlist=jieba.cut(text)
textcn=" ".join(wordlist)
print(textcn)

wordcloud = WordCloud(font_path = "C:\Windows\Fonts\simhei.ttf").generate(textcn)
image_produce = wordcloud.to_image()
image_produce.show()
# Out:
# 我爱你不是因为你是谁，而是因为我和你在一起的时候是谁。
# 没有人值得你流泪，值得让你这么做的人不会让你哭泣。
# 错过别人的最糟糕的方式是坐在他们旁边，知道你不能拥有他们。
# 纵然伤心，也不要皱眉，因为你不知道是谁爱上了你的笑容。
# 对世界而言，你可能是一个人，但对某个人来说，你可能是整个世界
# 不要把你的时间浪费在一个不愿在你身上浪费时间的男人/女人身上。
# 仅仅因为某人没有按你所希望的方式爱你，并不意味着他们没有全心全意地爱你。
# 不要努力，最好的事情总会在你最不期待的时候出现。
# 我爱你 不是 因为 你 是 谁 ， 而是 因为 我 和 你 在 一起 的 时候 是 谁 。
#  没有 人 值得 你 流泪 ， 值得 让 你 这么 做 的 人 不会 让 你 哭泣 。
#  错过 别人 的 最 糟糕 的 方式 是 坐在 他们 旁边 ， 知道 你 不能 拥有 他们 。
#  纵然 伤心 ， 也 不要 皱眉 ， 因为 你 不 知道 是 谁 爱 上 了 你 的 笑容 。
#  对 世界 而言 ， 你 可能 是 一个 人 ， 但 对 某个 人 来说 ， 你 可能 是 整个 世界
#  不要 把 你 的 时间 浪费 在 一个 不愿 在 你 身上 浪费时间 的 男人 / 女人 身上 。
#  仅仅 因为 某人 没有 按 你 所 希望 的 方式 爱 你 ， 并 不 意味着 他们 没有 全心全意 地爱 你 。
#  不要 努力 ， 最好 的 事情 总会 在 你 最 不 期待 的 时候 出现 。

# %%
from wordcloud import WordCloud
import PIL.Image as image

fp=open("love.txt")
text = fp.read()
wordcloud = WordCloud(font_path = "C:\Windows\Fonts\simhei.ttf").generate(text)
image_produce = wordcloud.to_image()
image_produce.show()

# %%
from wordcloud import WordCloud
import jieba
#jieba.suggest_freq(("我"), True)

jieba.suggest_freq(("如", "果"), tune = True)
print("/".join(jieba.cut("如果放到post中将出错。", HMM = False)))
# Out:
# 如/果/放到/post/中/将/出错/。

# %%
import jieba
seg_list = jieba.cut("我爱你不是因为你是谁，而是我爱你", cut_all=True)
print("Full Mode: " + "/ ".join(seg_list))
# Out:
# Full Mode: 我爱你/ 不是/ 是因为/ 因为/ 你/ 是/ 谁/ / / 而是/ 我爱你

# %%
from wordcloud import WordCloud
fp=open("lovecn.txt")
text = fp.read()
a="我"
wordcloud = WordCloud( stopwords=a,font_path = "C:\Windows\Fonts\simhei.ttf").generate(text)
image_produce = wordcloud.to_image()
image_produce.show()

# %%
from wordcloud import WordCloud
import jieba

fp=open("lovecn.txt")
text = fp.read()
print(text)
wordlist=jieba.cut(text)
textcn=" ".join(wordlist)
print(textcn)

wordcloud = WordCloud(font_path = "C:\Windows\Fonts\simhei.ttf").generate(textcn)

jieba.suggest_freq(('你的笑容'), True)
wordlist=jieba.cut(text)
textcn=" ".join(wordlist)
print(textcn)
# Out:
# 我爱你不是因为你是谁，而是因为我和你在一起的时候是谁。
# 没有人值得你流泪，值得让你这么做的人不会让你哭泣。
# 错过别人的最糟糕的方式是坐在他们旁边，知道你不能拥有他们。
# 纵然伤心，也不要皱眉，因为你不知道是谁爱上了你的笑容。
# 对世界而言，你可能是一个人，但对某个人来说，你可能是整个世界
# 不要把你的时间浪费在一个不愿在你身上浪费时间的男人/女人身上。
# 仅仅因为某人没有按你所希望的方式爱你，并不意味着他们没有全心全意地爱你。
# 不要努力，最好的事情总会在你最不期待的时候出现。
# 我爱你 不是 因为 你 是 谁 ， 而是 因为 我 和 你 在 一起 的 时候 是 谁 。
#  没有 人 值得 你 流泪 ， 值得 让 你 这么 做 的 人 不会 让 你 哭泣 。
#  错过 别人 的 最 糟糕 的 方式 是 坐在 他们 旁边 ， 知道 你 不能 拥有 他们 。
#  纵然 伤心 ， 也 不要 皱眉 ， 因为 你 不 知道 是 谁 爱 上 了 你 的 笑容 。
#  对 世界 而言 ， 你 可能 是 一个 人 ， 但 对 某个 人 来说 ， 你 可能 是 整个 世界
#  不要 把 你 的 时间 浪费 在 一个 不愿 在 你 身上 浪费时间 的 男人 / 女人 身上 。
#  仅仅 因为 某人 没有 按 你 所 希望 的 方式 爱 你 ， 并 不 意味着 他们 没有 全心全意 地爱 你 。
#  不要 努力 ， 最好 的 事情 总会 在 你 最 不 期待 的 时候 出现 。
# 我爱你 不是 因为 你 是 谁 ， 而是 因为 我 和 你 在 一起 的 时候 是 谁 。
#  没有 人 值得 你 流泪 ， 值得 让 你 这么 做 的 人 不会 让 你 哭泣 。
#  错过 别人 的 最 糟糕 的 方式 是 坐在 他们 旁边 ， 知道 你 不能 拥有 他们 。
#  纵然 伤心 ， 也 不要 皱眉 ， 因为 你 不 知道 是 谁 爱 上 了 你的笑容 。
#  对 世界 而言 ， 你 可能 是 一个 人 ， 但 对 某个 人 来说 ， 你 可能 是 整个 世界
#  不要 把 你 的 时间 浪费 在 一个 不愿 在 你 身上 浪费时间 的 男人 / 女人 身上 。
#  仅仅 因为 某人 没有 按 你 所 希望 的 方式 爱 你 ， 并 不 意味着 他们 没有 全心全意 地爱 你 。
#  不要 努力 ， 最好 的 事情 总会 在 你 最 不 期待 的 时候 出现 。

# %%
# 数学建模 仿真

# %% [markdown]
# # https://blog.csdn.net/weixin_41503009/article/details/81613044

# %%
import random
import numpy as np
#开车时间的仿真测试
s1 = 0;s3 = 0
for i in range(10000):
    s = random.random()
    
    if s<0.7:
        s1+=1
    elif s>0.9:
        s3+=1
print(s1/10000,1-s1/10000-s3/10000,s3/10000)
#人到达时刻仿真测试
s1,s2,s3,s4=0,0,0,0
for i in range(10000):
    s = random.random()
    if s<0.3:
        s1+=1
    elif s<0.7:
        s2+=1
    elif s<0.9:
        s3+=1
    else:
        s4+=1
print(s1/10000,s2/10000,s3/10000,s4/10000)
#火车运行时间仿真测试
s = np.random.normal(0,1,10000)
y = []
for i in range(10000):
    y[i] = 2*s[i]+30
    
#赶上火车的仿真结果
x1 = [random.random() for i in range(10000)]
x2 = [random.random() for i in range(10000)]
x3 = np.random.normal(0,1,10000)
s = 0
for i in range(10000):
    if x1[i]<0.7:
        T1=0
    elif x1[i]<0.9:
        T1=5
    else:T1=10
    
    T2=30+2*x3[i]
    if x2[i]<0.3:
        T3=28
    elif x2[i]<0.7:
        T3=30
    elif x2[i]<0.9:
        T3=32
    else:T3=34
#    print(T3)
    if (T3<T2+T1).all():
        s+=1
    continue
print(s/10000)
# Out:
# 0.699 0.20100000000000004 0.1
# 0.2982 0.4011 0.1961 0.1046
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-34-ea4e0af427b0> in <module>
#      28 y = []
#      29 for i in range(10001):
# ---> 30     y[i] = 2*s[i]+30
#      31
#      32 #赶上火车的仿真结果
#
# IndexError: list assignment index out of range

# %%
import random
c=[]
d=0


'''y = []
for i in range(10000):
    y[i] = 2*s[i]+30'''

s = np.random.normal(0,1,10000)
print(len(s))
# Out:
# 10000

# %%
# Out:
# '[title]' 不是内部或外部命令，也不是可运行的程序
# 或批处理文件。

# %% [markdown]
# # 机械臂仿真

# %%
import cv2
import numpy as np

img=cv2.imread("marm.jpg")
center=(200,100)
width=200
height=100
angle=10
rect=(center, (width, height), angle)
box = cv2.boxPoints(rect).astype(np.int0)
#print(box)
cv2.drawContours(img,[box],0,(255,0,0),3)
cv2.imshow("img",img)
cv2.waitKey()
cv2.destroyAllWindows()
#type(box[2])

# %% [markdown]
# # 画一个以左端为基准点同样角度的矩形

# %%
import cv2
import numpy as np
import math as m
img=cv2.imread("marm.jpg")
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
print(W,H)
img=cv2.resize(img,(W,H))
print(img.shape)
leftbuttom=(92,131)
width=200
height=100
angle=10
print(m.sin(angle))
print(m.cos(angle))

x=int(m.sin(angle/180*m.pi)*width/2)
y=int(m.cos(angle/188*m.pi)*width/2)
center=leftbuttom+np.array([y,x])
rect=(center, (width, height), angle)
box = cv2.boxPoints(rect).astype(np.int0)
print(box)
cv2.drawContours(img,[box],0,(255,0,0),3)
cv2.imshow("img",img)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# (1080, 1440, 3)
# 720 540
# (540, 720, 3)
# -0.5440211108893698
# -0.8390715290764524
# [[ 82 179]
#  [100  81]
#  [297 116]
#  [279 214]]

# %%
import cv2
import numpy as np

img=cv2.imread("marm.jpg")

#中心点，长度，角度
def drawlever(center,width,angle):
    height=100
    rect=(center, (width, height), angle)
    box = cv2.boxPoints(rect).astype(np.int0)
    cv2.drawContours(img,[box],0,(255,0,0),3)
    cv2.imshow("marm",img)

drawlever((650,250),800,3)    
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 封装成对象

# %%
import cv2
import numpy as np

img=cv2.imread("marm.jpg")
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
print(W,H)
img=cv2.resize(img,(W,H))
print(img.shape)

# 臂模型
class mlever():
    def __init__(self,center,width,angle):
        self.center=center
        self.width=width
        self.angle=angle

    def drawlever(self):
        center=self.center
        width=self.width
        angle=self.angle
        height=100
        rect=(center, (width, height), angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)
        
    def setlever(self,center,width,angle):
        self.center=center
        self.width=width
        self.angle=angle

        
ml01=mlever((315,120),400,3)    
ml02=mlever((380,245),340,140)
ml01.drawlever()
ml02.drawlever()

cv2.imshow("marm",img)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# (1080, 1440, 3)
# 720 540
# (540, 720, 3)

# %% [markdown]
# # 电机模型，先画出来圆形和长型

# %%
import cv2
import numpy as np

img=cv2.imread("marm.jpg")

#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
print(W,H)
img=cv2.resize(img,(W,H))
print(img.shape)

#画一条0度的直线 ，半径为r
angle=0
circlecenter=(200,100)
color=(0,255,0)
r=30
cv2.circle(img,circlecenter,r,color,5)
rect=(circlecenter,(2*r,4),angle)
box = cv2.boxPoints(rect).astype(np.int0)
cv2.drawContours(img,[box],0,(255,0,0),3)

angle=90
circlecenter=(260,360)
color=(0,255,0)
r=30
cv2.circle(img,circlecenter,r,color,5)
rect=(circlecenter,(2*r,4),angle)
box = cv2.boxPoints(rect).astype(np.int0)
cv2.drawContours(img,[box],0,(255,0,0),3)


cv2.imshow("img",img)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# (1080, 1440, 3)
# 720 540
# (540, 720, 3)

# %% [markdown]
# # 封装成函数

# %%
import cv2
import numpy as np

img=cv2.imread("marm.jpg")

#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
print(W,H)
img=cv2.resize(img,(W,H))
print(img.shape)

def drawmotor(circlecenter,angle):
    color=(0,255,0)
    r=30
    cv2.circle(img,circlecenter,r,color,5)
    rect=(circlecenter,(2*r,4),angle)
    box = cv2.boxPoints(rect).astype(np.int0)
    cv2.drawContours(img,[box],0,(255,0,0),3)

circlecenter=(0,0)
drawmotor(center,0)
#drawmotor(center,30)
#drawmotor(center,60)
#drawmotor(center,90)

cv2.imshow("img",img)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# (1080, 1440, 3)
# 720 540
# (540, 720, 3)

# %% [markdown]
# # 封装成对象

# %%
import cv2
import numpy as np

img=cv2.imread("marm.jpg")

#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
print(W,H)
img=cv2.resize(img,(W,H))
print(img.shape)
 # 封装成类
class mmotor():
    #初始化舵机
    def __init__(self,center,angle,fixangle):
        self.center=center
        self.angle=angle
        self.fixangle=fixangle
        
    def setfixangle(fixangle):
        self.fixangle=fixangle
        
    def setcenter(center):
        self.center=center
        
    def draw(self,angle):
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle+self.fixangle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)

m02=mmotor((260,360),0,0)
m01=mmotor((500,150),0,-30)
for i in range(90):
    m02.draw(i*10)
    m01.draw(i*10)
    cv2.imshow("img",img)
    cv2.waitKey(1000)

cv2.destroyAllWindows()
# Out:
# (1080, 1440, 3)
# 720 540
# (540, 720, 3)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-505955433cc9> in <module>
#      40     m01.draw(i*10)
#      41     cv2.imshow("img",img)
# ---> 42     cv2.waitKey(1000)
#      43
#      44 cv2.destroyAllWindows()
#
# KeyboardInterrupt:

# %%
import cv2
import numpy as np
import math  as mt

img=cv2.imread("marm.jpg")
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
print(W,H)
img=cv2.resize(img,(W,H))
imgcon=img.copy()
print(img.shape)

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            print("caculate center")
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            print(w,h)
            self.center=self.jointpoint-np.array([w,h])
            print(self.center)    
        rect=(self.center, (self.width,self.height), self.angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)          
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjoitpoint(self,jointpoint):
        self.jointpoint=jointpoint
        
ml02=mlever((380,245),100,10,0)
ml02.setjoitpoint((270,370))

for i in range(12):
    ml02.setangle(i*30)
    ml02.draw()
    cv2.imshow("marm",img)
    cv2.waitKey(1000)
    #恢复背景
    img=imgcon.copy()
cv2.destroyAllWindows()
# Out:
# (1080, 1440, 3)
# 720 540
# (540, 720, 3)
# caculate center
# 50 0
# [220 370]
# caculate center
# 43 24
# [227 346]
# caculate center
# 25 43
# [245 327]
# caculate center
# 0 50
# [270 320]
# caculate center
# -24 43
# [294 327]
# caculate center
# -43 24
# [313 346]
# caculate center
# -50 0
# [320 370]
# caculate center
# -43 -25
# [313 395]
# caculate center
# -25 -43
# [295 413]
# caculate center
# 0 -50
# [270 420]
# caculate center
# 25 -43
# [245 413]
# caculate center
# 43 -25
# [227 395]

# %% [markdown]
# # 一个电机与杆同时动

# %%
import cv2
import numpy as np
import math  as mt

img=cv2.imread("marm.jpg")

#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
print(W,H)
img=cv2.resize(img,(W,H))
print(img.shape)

#电机模型
class mmotor():
    def __init__(self,center,angle,fixangle):
        self.center=center
        self.angle=angle
        self.fixangle=fixangle
        
    def setfixangle(self,fixangle):
        self.fixangle=fixangle
        ,
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle+self.fixangle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.rightend=(0,0)
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            print("caculate center")
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            self.center=self.jointpoint-np.array([w,h])
            self.rightend=self.center-np.array([w,h])
            print(self.center)    
        rect=(self.center, (self.width,self.height), self.angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)          
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjoitpoint(self,jointpoint):
        self.jointpoint=jointpoint
        
m02=mmotor((260,360),0,0)
ml02=mlever((0,0),340,20,0)
ml02.setjoitpoint((260,360))
for i in range(18):
    angle=i*10
    m02.draw(angle)
    ml02.setangle(angle)
    ml02.draw()
    cv2.imshow("marm",img)
    cv2.waitKey(1000)
    #恢复背景
    img=imgcon.copy()

cv2.destroyAllWindows()
# Out:
# (1080, 1440, 3)
# 720 540
# (540, 720, 3)
# caculate center
# [ 90 360]
# caculate center
# [ 93 331]
# caculate center
# [101 302]
# caculate center
# [113 276]
# caculate center
# [130 251]
# caculate center
# [151 230]
# caculate center
# [175 213]
# caculate center
# [202 201]
# caculate center
# [231 193]
# caculate center
# [260 190]
# caculate center
# [289 193]
# caculate center
# [318 201]
# caculate center
# [344 213]
# caculate center
# [369 230]
# caculate center
# [390 251]
# caculate center
# [407 276]
# caculate center
# [419 302]
# caculate center
# [427 331]

# %%
import cv2
import numpy as np
import math  as mt

img=cv2.imread("marm.jpg")

#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
print(W,H)
img=cv2.resize(img,(W,H))
print(img.shape)

#电机模型
class mmotor():
    def __init__(self,center,angle,startangle):
        self.center=center
        self.angle=angle
        self.startangle=startangle
        
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        self.angle=angle
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)
    def drawrelative(self,relaangle):
        self.angle=self.startangle+relaangle
        self.draw(self.angle)

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.rightend=(width,0)
        self.rightendr=10
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            self.center=(self.jointpoint[0]-w,self.jointpoint[1]-h)
            self.rightend=(self.jointpoint[0]-w*2,self.jointpoint[1]-h*2)
        rect=(self.center, (self.width,self.height), self.angle)
        box = cv2.boxPoints(rect).astype(np.int0)        
        cv2.drawContours(img,[box],0,(255,0,0),3)          
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjointpoint(self,jointpoint):
        self.jointpoint=jointpoint
    def drawrightend(self):
        cv2.circle(img,self.rightend,self.rightendr,(0,0,255),3)
        

m01=mmotor((500,140),0,0)
ml01=mlever((0,0),340,20,0)
ml01.setjointpoint((460,260))
m02=mmotor((260,360),0,0)
ml02=mlever((0,0),340,20,0)
ml02.setjointpoint((260,360))

for i in range(18):
    angle=i*10
    #电机02
    m02.drawrelative(angle)
    #杆02
    ml02.setangle(angle)
    ml02.draw()
    #电机01放在杆02的右端
    m01.setcenter(ml02.rightend)
    m01.startangle=180+m02.angle
    #电机01目前保持30度不变
    m01.drawrelative(30)
    #杆01固定在电机01中心，角度与电机01一样
    ml01.setjointpoint(m01.center)
    ml01.setangle(m01.angle)
    ml01.draw()
    ml01.drawrightend()
    cv2.imshow("marm",img)
    cv2.waitKey(1000)
    #恢复背景
    img=imgcon.copy()

cv2.destroyAllWindows()
# Out:
# (1080, 1440, 3)
# 720 540
# (540, 720, 3)

# %% [markdown]
# # 添加吸盘模型，永远垂直

# %%
import cv2
import numpy as np
import math  as mt

img=cv2.imread("marm.jpg")
#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
BW=int(W*1.5)+1
print(W,H)
img=cv2.resize(img,(W,H))
img= cv2.copyMakeBorder(img,0,0,400,0,cv2.BORDER_CONSTANT,value=(100,100,0))
imgcon=img.copy()
print(img.shape)

#电机模型
class mmotor():
    def __init__(self,center,angle,startangle):
        self.center=center
        self.angle=angle
        self.startangle=startangle
        
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        self.angle=angle
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)
    def drawrelative(self,relaangle):
        self.angle=self.startangle+relaangle
        self.draw(self.angle)

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.rightend=(width,0)
        self.rightendr=10
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            self.center=(self.jointpoint[0]-w,self.jointpoint[1]-h)
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(self.jointpoint[0]-w*2,self.jointpoint[1]-h*2)
        else:
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(int((box[2][0]+box[3][0])/2),int((box[2][1]+box[3][1])/2))
        cv2.drawContours(img,[box],0,(255,0,0),3)          
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjointpoint(self,jointpoint):
        self.jointpoint=jointpoint
    def drawrightend(self):
        cv2.circle(img,self.rightend,self.rightendr,(0,0,255),3)

class Marm():
    def __init__(self,m01,m02,m03,ml01,ml02,ml03):
        self.m01=m01
        self.m02=m02
        self.m03=m03        
        self.ml01=ml01
        self.ml02=ml02
        self.ml02=ml03 
        self.angle1=0
        self.angle2=0
        self.angle3=0
        ml02.setjointpoint(m02.center)
    def draw(self,angle1,angle2):
        #电机02
        m02.drawrelative(angle2)
        #杆02
        ml02.setangle(angle2)
        ml02.draw()
        #电机01放在杆02的右端
        m01.setcenter(ml02.rightend)
        m01.startangle=180+m02.angle
        #电机01目前保持30度不变
        if angle1<=0:
            angle1=0
        m01.drawrelative(angle1)
        #杆01固定在电机01中心，角度与电机01一样
        ml01.setjointpoint(m01.center)
        ml01.setangle(m01.angle)
        ml01.draw()
        ml01.drawrightend()
        #杆03永远保持垂直，中心点位于杆01右端下方
        ml03.setangle(90)
        L=int(ml03.width/2)
        ml03.center=np.add(ml01.rightend,(0,L))
        ml03.draw()
        ml03.drawrightend()
        

m02=mmotor((260+400,360),0,0)
m01=mmotor((0,0),0,0)
m03=mmotor((0,0),0,0)
ml01=mlever((0,0),350,20,0)
ml02=mlever((0,0),340,20,0)
ml03=mlever((0,0),100,20,0)
marm=Marm(m01,m02,m03,ml01,ml02,ml03)

for i in range(30):
    angle=i*5
    angle1=180-angle*2+10
    marm.draw(angle1,angle)
    cv2.imshow("marm",img)
    cv2.waitKey(300)
    #恢复背景
    img=imgcon.copy()

for i in range(15):
    angle=150-i*5
    angle1=45
    marm.draw(angle1,angle)
    cv2.imshow("marm",img)
    cv2.waitKey(300)
    #恢复背景
    img=imgcon.copy()

cv2.destroyAllWindows()
# Out:
# (1080, 1440, 3)
# 720 540
# (540, 1120, 3)

# %%
import cv2
import numpy as np
import math  as mt

img=cv2.imread("marm.jpg")
#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
BW=int(W*1.5)+1
print(W,H)
img=cv2.resize(img,(W,H))
img= cv2.copyMakeBorder(img,0,0,400,0,cv2.BORDER_CONSTANT,value=(100,100,0))
imgcon=img.copy()
print(img.shape)

#电机模型
class mmotor():
    def __init__(self,center,angle,startangle):
        self.center=center
        self.angle=angle
        self.startangle=startangle
        
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        self.angle=angle
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)
    def drawrelative(self,relaangle):
        self.angle=self.startangle+relaangle
        self.draw(self.angle)

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.rightend=(width,0)
        self.rightendr=10
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            self.center=(self.jointpoint[0]-w,self.jointpoint[1]-h)
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(self.jointpoint[0]-w*2,self.jointpoint[1]-h*2)
        else:
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(int((box[2][0]+box[3][0])/2),int((box[2][1]+box[3][1])/2))
        cv2.drawContours(img,[box],0,(255,0,0),3)          
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjointpoint(self,jointpoint):
        self.jointpoint=jointpoint
    def drawrightend(self):
        cv2.circle(img,self.rightend,self.rightendr,(0,0,255),3)

class Marm():
    def __init__(self,m01,m02,m03,ml01,ml02,ml03):
        self.m01=m01
        self.m02=m02
        self.m03=m03        
        self.ml01=ml01
        self.ml02=ml02
        self.ml02=ml03 
        self.angle1=0
        self.angle2=0
        self.angle3=0
        ml02.setjointpoint(m02.center)
    def xytoq(self,x,y):
        L1=ml01.width
        L2=ml02.width
        L3=mt.sqrt(y*y+x*x)
        #L3最长不超过两臂之和
        if L3>L1+L2:
            L3=L1+L2-4
        #L3最短不少于两臂之差
        if L3<abs(L1-L2):
            L3=abs(L1-L2)+4
        p=(L1+L2+L3)/2
        S=mt.sqrt(p*(p-L1)*(p-L2)*(p-L3))
        h=S*2/L3
        Q5=mt.asin(h/L2)/mt.pi*180
        Q4=mt.asin(y/L3)/mt.pi*180
        Q7=mt.asin(h/L1)/mt.pi*180
        Q1=180-Q5-Q7
        Q2=Q5+Q4
        #print("Q1,Q2",Q1,Q2)
        return Q1,Q2
    def draw(self,angle1,angle2):
        #电机02
        m02.drawrelative(angle2)
        #杆02
        ml02.setangle(angle2)
        ml02.draw()
        #电机01放在杆02的右端
        m01.setcenter(ml02.rightend)
        m01.startangle=180+m02.angle
        #电机01目前保持30度不变
        if angle1<=0:
            angle1=0
        m01.drawrelative(angle1)
        #杆01固定在电机01中心，角度与电机01一样
        ml01.setjointpoint(m01.center)
        ml01.setangle(m01.angle)
        ml01.draw()
        ml01.drawrightend()
        #杆03永远保持垂直，中心点位于杆01右端下方
        ml03.setangle(90)
        L=int(ml03.width/2)
        ml03.center=np.add(ml01.rightend,(0,L))
        ml03.draw()
        ml03.drawrightend()
        

m02=mmotor((260+400,360),0,0)
m01=mmotor((0,0),0,0)
m03=mmotor((0,0),0,0)
ml01=mlever((0,0),350,20,0)
ml02=mlever((0,0),340,20,0)
ml03=mlever((0,0),100,20,0)
marm=Marm(m01,m02,m03,ml01,ml02,ml03)

for i in range(60):
    x=i*10+10
    y=0
    angle1,angle2=marm.xytoq(x,y)
    marm.draw(angle1,angle2)
    cv2.imshow("marm",img)
    cv2.waitKey(300)
    #恢复背景
    img=imgcon.copy()

for i in range(60):
    x=650-i*10
    y=0
    angle1,angle2=marm.xytoq(x,y)
    marm.draw(angle1,angle2)
    cv2.imshow("marm",img)
    cv2.waitKey(300)
    #恢复背景
    img=imgcon.copy()

    
    
cv2.destroyAllWindows()
# Out:
# (1080, 1440, 3)
# 720 540
# (540, 1120, 3)

# %% [markdown]
# # 位置 xy 通过pwm参数仿真运行

# %%
import cv2
import numpy as np
import math  as mt

img=cv2.imread("marm.jpg")
#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
BW=int(W*1.5)+1
print(W,H)
img=cv2.resize(img,(W,H))
img= cv2.copyMakeBorder(img,0,0,400,0,cv2.BORDER_CONSTANT,value=(100,100,0))
imgcon=img.copy()
print(img.shape)

#电机模型
class mmotor():
    def __init__(self,center,angle,startangle,maxangle):
        self.center=center
        self.angle=angle
        self.startangle=startangle
        self.maxangle=maxangle
        self.relaangle=0
        self.pwm=500
        self.facetome=False
        
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        self.angle=angle
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)
    def drawrelative(self,relaangle):
        if relaangle >self.maxangle:
            relaangle=self.maxangle
        self.relaangle=relaangle
        self.angle=self.startangle+self.relaangle
        self.pwm=500+self.relaangle*180/self.maxangle*(2500-500)/180
        self.draw(self.angle)
        

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.rightend=(width,0)
        self.rightendr=10
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            self.center=(self.jointpoint[0]-w,self.jointpoint[1]-h)
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(self.jointpoint[0]-w*2,self.jointpoint[1]-h*2)
        else:
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(int((box[2][0]+box[3][0])/2),int((box[2][1]+box[3][1])/2))
        cv2.drawContours(img,[box],0,(255,0,0),3)          
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjointpoint(self,jointpoint):
        self.jointpoint=jointpoint
    def drawrightend(self):
        cv2.circle(img,self.rightend,self.rightendr,(0,0,255),3)

class Marm():
    def __init__(self,m01,m02,m03,ml01,ml02,ml03):
        self.m01=m01
        self.m02=m02
        self.m03=m03        
        self.ml01=ml01
        self.ml02=ml02
        self.ml03=ml03 
        self.angle1=0
        self.angle2=0
        self.angle3=0
        #将梁2固定在电机2的中心
        self.ml02.setjointpoint(self.m02.center)
    def xytoq(self,x,y):
        L1=self.ml01.width
        L2=self.ml02.width
        L3=mt.sqrt(y*y+x*x)
        #L3最长不超过两臂之和
        if L3>L1+L2:
            L3=L1+L2-4
        #L3最短不少于两臂之差
        if L3<abs(L1-L2):
            L3=abs(L1-L2)+4
        p=(L1+L2+L3)/2
        S=mt.sqrt(p*(p-L1)*(p-L2)*(p-L3))
        h=S*2/L3
        Q5=mt.asin(h/L2)/mt.pi*180
        Q4=mt.asin(y/L3)/mt.pi*180
        Q7=mt.asin(h/L1)/mt.pi*180
        Q1=180-Q5-Q7
        Q2=Q5+Q4
        #print("Q1,Q2",Q1,Q2)
        return Q1,Q2
    
    #输入参数为屏幕角度，不考虑电机面对面放置
    def scrdraw(self,angle1,angle2):
        #电机02
        self.m02.drawrelative(angle2)
        #杆02
        self.ml02.setangle(angle2)
        self.ml02.draw()
        #电机01放在杆02的右端
        self.m01.setcenter(self.ml02.rightend)
        self.m01.startangle=180+self.m02.angle
        if angle1<=0:
            angle1=0
        self.m01.drawrelative(angle1)
        #杆01固定在电机01中心，角度与电机01一样
        self.ml01.setjointpoint(self.m01.center)
        self.ml01.setangle(self.m01.angle)
        self.ml01.draw()
        self.ml01.drawrightend()
        #杆03永远保持垂直，中心点位于杆01右端下方
        self.ml03.setangle(90)
        L=int(self.ml03.width/2)
        self.ml03.center=np.add(self.ml01.rightend,(0,L))
        self.ml03.draw()
        self.ml03.drawrightend()
        
    #输入角度考虑电机是否对面装配，然后画在图上   
    def robodraw(self,angle1,angle2):
        mangle1=angle1
        mangle2=angle2
        if self.m01.facetome == True:
            print("facetome")
            mangle1=self.m01.maxangle-angle1
        if self.m02.facetome == True:
            mangle2=slef.m02.maxangle-angle2
        print("mangle1,mangle2",mangle1,mangle2)
        self.scrdraw(mangle1,mangle2)
        
    def drawpwm(self,pwm1,pwm2):
        angle1disp=int((pwm1-500)/2000*180)
        angle2disp=int((pwm2-500)/2000*180)
        angel1=int(angle1disp*self.m01.maxangle/180)
        angel2=int(angle2disp*self.m02.maxangle/180)
        
        A1=180+50-(angel1+angel2)
        print("angle1disp,angle2disp,A1,%x,%x,"%(pwm1,pwm2),angle1disp,angle2disp,A1)
        self.robodraw(A1,angel2)
    def xytopwm(self,x,y):
        q1,q2=self.xytoq(x,y)
        # q1=180+50-(q2+pwmq1)
        pwmq1=180+50-(q1+q2)
        pwmq2=q2
        pwm1=int(pwmq1/180*2000+500)
        pwm2=int(pwmq2/180*2000+500)
        return pwm1,pwm2
    
    def serwrite(self,pwm1,pwm2):
        print("TBD,serialwrite %x %x"%(pwm1,pwm2))
        return
    
    def robotTwin(self,x,y):
        pwm1,pwm2=self.xytopwm(x,y)
        self.drawpwm(pwm1,pwm2)
        self.serwrite(pwm1,pwm2)
        
#配置零件舵机
mM02=mmotor((260+400,360),0,0,180)
mM01=mmotor((0,0),0,0,180)
mM03=mmotor((0,0),0,0,180)
#配置零件梁
mMl01=mlever((0,0),300,20,0)
mMl02=mlever((0,0),300,20,0)
mMl03=mlever((0,0),100,20,0)
#组装成机械臂
marm=Marm(mM01,mM02,mM03,mMl01,mMl02,mMl03)

for i in range(50):
    x=i*10+100
    y=0
    marm.robotTwin(x,y)
    cv2.imshow("marm",img)
    cv2.waitKey(300)
    #恢复背景
    img=imgcon.copy()

for i in range(50):
    x=600-i*10
    y=0
    marm.robotTwin(x,y)
    cv2.imshow("marm",img)
    cv2.waitKey(300)
    #恢复背景
    img=imgcon.copy()

cv2.destroyAllWindows()
# Out:
# (1080, 1440, 3)
# 720 540
# (540, 1120, 3)
# angle1disp,angle2disp,A1,79c,571, 130 80 20
# mangle1,mangle2 20 80
# TBD,serialwrite 79c 571
# angle1disp,angle2disp,A1,792,566, 129 79 22
# mangle1,mangle2 22 79
# TBD,serialwrite 792 566
# angle1disp,angle2disp,A1,787,55b, 128 78 24
# mangle1,mangle2 24 78
# TBD,serialwrite 787 55b
# angle1disp,angle2disp,A1,77c,550, 127 77 26
# mangle1,mangle2 26 77
# TBD,serialwrite 77c 550
# angle1disp,angle2disp,A1,771,546, 126 76 28
# mangle1,mangle2 28 76
# TBD,serialwrite 771 546
# angle1disp,angle2disp,A1,766,53b, 125 75 30
# mangle1,mangle2 30 75
# TBD,serialwrite 766 53b
# angle1disp,angle2disp,A1,75b,530, 124 74 32
# mangle1,mangle2 32 74
# TBD,serialwrite 75b 530
# angle1disp,angle2disp,A1,750,525, 123 73 34
# mangle1,mangle2 34 73
# TBD,serialwrite 750 525
# angle1disp,angle2disp,A1,745,51a, 122 72 36
# mangle1,mangle2 36 72
# TBD,serialwrite 745 51a
# angle1disp,angle2disp,A1,73a,50e, 121 71 38
# mangle1,mangle2 38 71
# TBD,serialwrite 73a 50e
# angle1disp,angle2disp,A1,72f,503, 120 70 40
# mangle1,mangle2 40 70
# TBD,serialwrite 72f 503
# angle1disp,angle2disp,A1,723,4f8, 119 69 42
# mangle1,mangle2 42 69
# TBD,serialwrite 723 4f8
# angle1disp,angle2disp,A1,718,4ec, 118 68 44
# mangle1,mangle2 44 68
# TBD,serialwrite 718 4ec
# angle1disp,angle2disp,A1,70d,4e1, 117 67 46
# mangle1,mangle2 46 67
# TBD,serialwrite 70d 4e1
# angle1disp,angle2disp,A1,701,4d6, 116 66 48
# mangle1,mangle2 48 66
# TBD,serialwrite 701 4d6
# angle1disp,angle2disp,A1,6f5,4ca, 115 65 50
# mangle1,mangle2 50 65
# TBD,serialwrite 6f5 4ca
# angle1disp,angle2disp,A1,6ea,4be, 114 64 52
# mangle1,mangle2 52 64
# TBD,serialwrite 6ea 4be
# angle1disp,angle2disp,A1,6de,4b2, 113 63 54
# mangle1,mangle2 54 63
# TBD,serialwrite 6de 4b2
# angle1disp,angle2disp,A1,6d2,4a6, 112 62 56
# mangle1,mangle2 56 62
# TBD,serialwrite 6d2 4a6
# angle1disp,angle2disp,A1,6c6,49a, 111 61 58
# mangle1,mangle2 58 61
# TBD,serialwrite 6c6 49a
# angle1disp,angle2disp,A1,6ba,48e, 109 59 62
# mangle1,mangle2 62 59
# TBD,serialwrite 6ba 48e
# angle1disp,angle2disp,A1,6ad,482, 108 58 64
# mangle1,mangle2 64 58
# TBD,serialwrite 6ad 482
# angle1disp,angle2disp,A1,6a1,475, 107 57 66
# mangle1,mangle2 66 57
# TBD,serialwrite 6a1 475
# angle1disp,angle2disp,A1,694,469, 106 56 68
# mangle1,mangle2 68 56
# TBD,serialwrite 694 469
# angle1disp,angle2disp,A1,688,45c, 105 55 70
# mangle1,mangle2 70 55
# TBD,serialwrite 688 45c
# angle1disp,angle2disp,A1,67b,44f, 104 54 72
# mangle1,mangle2 72 54
# TBD,serialwrite 67b 44f
# angle1disp,angle2disp,A1,66d,442, 103 53 74
# mangle1,mangle2 74 53
# TBD,serialwrite 66d 442
# angle1disp,angle2disp,A1,660,434, 101 51 78
# mangle1,mangle2 78 51
# TBD,serialwrite 660 434
# angle1disp,angle2disp,A1,652,427, 100 50 80
# mangle1,mangle2 80 50
# TBD,serialwrite 652 427
# angle1disp,angle2disp,A1,645,419, 99 49 82
# mangle1,mangle2 82 49
# TBD,serialwrite 645 419
# angle1disp,angle2disp,A1,636,40b, 98 48 84
# mangle1,mangle2 84 48
# TBD,serialwrite 636 40b
# angle1disp,angle2disp,A1,628,3fd, 96 46 88
# mangle1,mangle2 88 46
# TBD,serialwrite 628 3fd
# angle1disp,angle2disp,A1,619,3ee, 95 45 90
# mangle1,mangle2 90 45
# TBD,serialwrite 619 3ee
# angle1disp,angle2disp,A1,60a,3df, 94 44 92
# mangle1,mangle2 92 44
# TBD,serialwrite 60a 3df
# angle1disp,angle2disp,A1,5fb,3cf, 92 42 96
# mangle1,mangle2 96 42
# TBD,serialwrite 5fb 3cf
# angle1disp,angle2disp,A1,5eb,3c0, 91 41 98
# mangle1,mangle2 98 41
# TBD,serialwrite 5eb 3c0
# angle1disp,angle2disp,A1,5db,3af, 89 39 102
# mangle1,mangle2 102 39
# TBD,serialwrite 5db 3af
# angle1disp,angle2disp,A1,5ca,39f, 88 38 104
# mangle1,mangle2 104 38
# TBD,serialwrite 5ca 39f
# angle1disp,angle2disp,A1,5b9,38d, 86 36 108
# mangle1,mangle2 108 36
# TBD,serialwrite 5b9 38d
# angle1disp,angle2disp,A1,5a7,37b, 85 35 110
# mangle1,mangle2 110 35
# TBD,serialwrite 5a7 37b
# angle1disp,angle2disp,A1,594,368, 83 33 114
# mangle1,mangle2 114 33
# TBD,serialwrite 594 368
# angle1disp,angle2disp,A1,580,355, 81 31 118
# mangle1,mangle2 118 31
# TBD,serialwrite 580 355
# angle1disp,angle2disp,A1,56c,340, 79 29 122
# mangle1,mangle2 122 29
# TBD,serialwrite 56c 340
# angle1disp,angle2disp,A1,556,32a, 77 27 126
# mangle1,mangle2 126 27
# TBD,serialwrite 556 32a
# angle1disp,angle2disp,A1,53e,313, 75 25 130
# mangle1,mangle2 130 25
# TBD,serialwrite 53e 313
# angle1disp,angle2disp,A1,525,2f9, 73 23 134
# mangle1,mangle2 134 23
# TBD,serialwrite 525 2f9
# angle1disp,angle2disp,A1,509,2dd, 71 20 139
# mangle1,mangle2 139 20
# TBD,serialwrite 509 2dd
# angle1disp,angle2disp,A1,4e9,2be, 68 18 144
# mangle1,mangle2 144 18
# TBD,serialwrite 4e9 2be
# angle1disp,angle2disp,A1,4c4,298, 64 14 152
# mangle1,mangle2 152 14
# TBD,serialwrite 4c4 298
# angle1disp,angle2disp,A1,493,268, 60 10 160
# mangle1,mangle2 160 10
# TBD,serialwrite 493 268
# angle1disp,angle2disp,A1,41f,1f4, 49 0 181
# mangle1,mangle2 181 0
# TBD,serialwrite 41f 1f4
# angle1disp,angle2disp,A1,493,268, 60 10 160
# mangle1,mangle2 160 10
# TBD,serialwrite 493 268
# angle1disp,angle2disp,A1,4c4,298, 64 14 152
# mangle1,mangle2 152 14
# TBD,serialwrite 4c4 298
# angle1disp,angle2disp,A1,4e9,2be, 68 18 144
# mangle1,mangle2 144 18
# TBD,serialwrite 4e9 2be
# angle1disp,angle2disp,A1,509,2dd, 71 20 139
# mangle1,mangle2 139 20
# TBD,serialwrite 509 2dd
# angle1disp,angle2disp,A1,525,2f9, 73 23 134
# mangle1,mangle2 134 23
# TBD,serialwrite 525 2f9
# angle1disp,angle2disp,A1,53e,313, 75 25 130
# mangle1,mangle2 130 25
# TBD,serialwrite 53e 313
# angle1disp,angle2disp,A1,556,32a, 77 27 126
# mangle1,mangle2 126 27
# TBD,serialwrite 556 32a
# angle1disp,angle2disp,A1,56c,340, 79 29 122
# mangle1,mangle2 122 29
# TBD,serialwrite 56c 340
# angle1disp,angle2disp,A1,580,355, 81 31 118
# mangle1,mangle2 118 31
# TBD,serialwrite 580 355
# angle1disp,angle2disp,A1,594,368, 83 33 114
# mangle1,mangle2 114 33
# TBD,serialwrite 594 368
# angle1disp,angle2disp,A1,5a7,37b, 85 35 110
# mangle1,mangle2 110 35
# TBD,serialwrite 5a7 37b
# angle1disp,angle2disp,A1,5b9,38d, 86 36 108
# mangle1,mangle2 108 36
# TBD,serialwrite 5b9 38d
# angle1disp,angle2disp,A1,5ca,39f, 88 38 104
# mangle1,mangle2 104 38
# TBD,serialwrite 5ca 39f
# angle1disp,angle2disp,A1,5db,3af, 89 39 102
# mangle1,mangle2 102 39
# TBD,serialwrite 5db 3af
# angle1disp,angle2disp,A1,5eb,3c0, 91 41 98
# mangle1,mangle2 98 41
# TBD,serialwrite 5eb 3c0
# angle1disp,angle2disp,A1,5fb,3cf, 92 42 96
# mangle1,mangle2 96 42
# TBD,serialwrite 5fb 3cf
# angle1disp,angle2disp,A1,60a,3df, 94 44 92
# mangle1,mangle2 92 44
# TBD,serialwrite 60a 3df
# angle1disp,angle2disp,A1,619,3ee, 95 45 90
# mangle1,mangle2 90 45
# TBD,serialwrite 619 3ee
# angle1disp,angle2disp,A1,628,3fd, 96 46 88
# mangle1,mangle2 88 46
# TBD,serialwrite 628 3fd
# angle1disp,angle2disp,A1,636,40b, 98 48 84
# mangle1,mangle2 84 48
# TBD,serialwrite 636 40b
# angle1disp,angle2disp,A1,645,419, 99 49 82
# mangle1,mangle2 82 49
# TBD,serialwrite 645 419
# angle1disp,angle2disp,A1,652,427, 100 50 80
# mangle1,mangle2 80 50
# TBD,serialwrite 652 427
# angle1disp,angle2disp,A1,660,434, 101 51 78
# mangle1,mangle2 78 51
# TBD,serialwrite 660 434
# angle1disp,angle2disp,A1,66d,442, 103 53 74
# mangle1,mangle2 74 53
# TBD,serialwrite 66d 442
# angle1disp,angle2disp,A1,67b,44f, 104 54 72
# mangle1,mangle2 72 54
# TBD,serialwrite 67b 44f
# angle1disp,angle2disp,A1,688,45c, 105 55 70
# mangle1,mangle2 70 55
# TBD,serialwrite 688 45c
# angle1disp,angle2disp,A1,694,469, 106 56 68
# mangle1,mangle2 68 56
# TBD,serialwrite 694 469
# angle1disp,angle2disp,A1,6a1,475, 107 57 66
# mangle1,mangle2 66 57
# TBD,serialwrite 6a1 475
# angle1disp,angle2disp,A1,6ad,482, 108 58 64
# mangle1,mangle2 64 58
# TBD,serialwrite 6ad 482
# angle1disp,angle2disp,A1,6ba,48e, 109 59 62
# mangle1,mangle2 62 59
# TBD,serialwrite 6ba 48e
# angle1disp,angle2disp,A1,6c6,49a, 111 61 58
# mangle1,mangle2 58 61
# TBD,serialwrite 6c6 49a
# angle1disp,angle2disp,A1,6d2,4a6, 112 62 56
# mangle1,mangle2 56 62
# TBD,serialwrite 6d2 4a6
# angle1disp,angle2disp,A1,6de,4b2, 113 63 54
# mangle1,mangle2 54 63
# TBD,serialwrite 6de 4b2
# angle1disp,angle2disp,A1,6ea,4be, 114 64 52
# mangle1,mangle2 52 64
# TBD,serialwrite 6ea 4be
# angle1disp,angle2disp,A1,6f5,4ca, 115 65 50
# mangle1,mangle2 50 65
# TBD,serialwrite 6f5 4ca
# angle1disp,angle2disp,A1,701,4d6, 116 66 48
# mangle1,mangle2 48 66
# TBD,serialwrite 701 4d6
# angle1disp,angle2disp,A1,70d,4e1, 117 67 46
# mangle1,mangle2 46 67
# TBD,serialwrite 70d 4e1
# angle1disp,angle2disp,A1,718,4ec, 118 68 44
# mangle1,mangle2 44 68
# TBD,serialwrite 718 4ec
# angle1disp,angle2disp,A1,723,4f8, 119 69 42
# mangle1,mangle2 42 69
# TBD,serialwrite 723 4f8
# angle1disp,angle2disp,A1,72f,503, 120 70 40
# mangle1,mangle2 40 70
# TBD,serialwrite 72f 503
# angle1disp,angle2disp,A1,73a,50e, 121 71 38
# mangle1,mangle2 38 71
# TBD,serialwrite 73a 50e
# angle1disp,angle2disp,A1,745,51a, 122 72 36
# mangle1,mangle2 36 72
# TBD,serialwrite 745 51a
# angle1disp,angle2disp,A1,750,525, 123 73 34
# mangle1,mangle2 34 73
# TBD,serialwrite 750 525
# angle1disp,angle2disp,A1,75b,530, 124 74 32
# mangle1,mangle2 32 74
# TBD,serialwrite 75b 530
# angle1disp,angle2disp,A1,766,53b, 125 75 30
# mangle1,mangle2 30 75
# TBD,serialwrite 766 53b
# angle1disp,angle2disp,A1,771,546, 126 76 28
# mangle1,mangle2 28 76
# TBD,serialwrite 771 546
# angle1disp,angle2disp,A1,77c,550, 127 77 26
# mangle1,mangle2 26 77
# TBD,serialwrite 77c 550
# angle1disp,angle2disp,A1,787,55b, 128 78 24
# mangle1,mangle2 24 78
# TBD,serialwrite 787 55b
# angle1disp,angle2disp,A1,792,566, 129 79 22
# mangle1,mangle2 22 79
# TBD,serialwrite 792 566

# %% [markdown]
# # 添加串口控制

# %%
import cv2
import numpy as np
import math  as mt
import serial
import serial.tools.list_ports
import string
import binascii
import time


img=cv2.imread("marm.jpg")
#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
BW=int(W*1.5)+1
print(W,H)
img=cv2.resize(img,(W,H))
img= cv2.copyMakeBorder(img,0,0,400,0,cv2.BORDER_CONSTANT,value=(100,100,0))
imgcon=img.copy()
print(img.shape)

#电机模型
class mmotor():
    def __init__(self,center,angle,startangle,maxangle):
        self.center=center
        self.angle=angle
        self.startangle=startangle
        self.maxangle=maxangle
        self.relaangle=0
        self.pwm=500
        self.facetome=False
        
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        self.angle=angle
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)
    def drawrelative(self,relaangle):
        if relaangle >self.maxangle:
            relaangle=self.maxangle
        self.relaangle=relaangle
        self.angle=self.startangle+self.relaangle
        self.pwm=500+self.relaangle*180/self.maxangle*(2500-500)/180
        self.draw(self.angle)
        

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.rightend=(width,0)
        self.rightendr=10
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            self.center=(self.jointpoint[0]-w,self.jointpoint[1]-h)
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(self.jointpoint[0]-w*2,self.jointpoint[1]-h*2)
        else:
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(int((box[2][0]+box[3][0])/2),int((box[2][1]+box[3][1])/2))
        cv2.drawContours(img,[box],0,(255,0,0),3)          
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjointpoint(self,jointpoint):
        self.jointpoint=jointpoint
    def drawrightend(self):
        cv2.circle(img,self.rightend,self.rightendr,(0,0,255),3)

class Marm():
    def __init__(self,m01,m02,m03,ml01,ml02,ml03):
        self.m01=m01
        self.m02=m02
        self.m03=m03        
        self.ml01=ml01
        self.ml02=ml02
        self.ml03=ml03 
        self.angle1=0
        self.angle2=0
        self.angle3=0
        self.ser=None
        #将梁2固定在电机2的中心
        self.ml02.setjointpoint(self.m02.center)
        #打开串口
        ports = list(serial.tools.list_ports.comports())
        print (ports)
        #便利 寻找串口
        for p in ports:
            print (p[1])
            if "serial" in p[1] or "CH340" in p[1]:
                self.ser=serial.Serial(port=p[0])
                if self.ser is not None:
                    print(self.ser)
                    print("serial conected")
                else:
                    print("serial not connected")
                    return
            else:
                print ("No CH340 Device was found connected to the computer")
                return
        self.robotinit()
    def robotinit(self):
        if self.ser is None:
            return
        m0=bytes.fromhex('ff 01 00 08 00')# 舵机0速度为 72
        m1=bytes.fromhex('ff 01 01 08 00')# 舵机1速度为 72
        m2=bytes.fromhex('ff 01 02 08 00')# 舵机2速度为 72
        mo0=bytes.fromhex('ff 02 00 dc 05')#设置初始舵机0位置
        mo1=bytes.fromhex('ff 02 01 82 07')#设置初始舵机1的位置
        mo2 = bytes.fromhex('ff 02 02 dc 05')#设置初始舵机2的位置
        mo3 = bytes.fromhex('ff 02 03 dc 05')#设置初始舵机3的位置
        self.ser.write(m0)
        self.ser.write(m1)
        self.ser.write(m2)
        self.ser.write(mo0)
        self.ser.write(mo1)
        self.ser.write(mo2)
        self.ser.write(mo3)
    def xytoq(self,x,y):
        L1=self.ml01.width
        L2=self.ml02.width
        L3=mt.sqrt(y*y+x*x)+0.01
        #L3最长不超过两臂之和
        if L3>L1+L2:
            L3=L1+L2-4
        #L3最短不少于两臂之差
        if L3<abs(L1-L2):
            L3=abs(L1-L2)+4
        p=(L1+L2+L3)/2
        S=mt.sqrt(p*(p-L1)*(p-L2)*(p-L3))
        h=S*2/L3
        Q5=mt.asin(h/L2)/mt.pi*180
        Q4=mt.asin(y/L3)/mt.pi*180
        Q7=mt.asin(h/L1)/mt.pi*180
        Q1=180-Q5-Q7
        Q2=Q5+Q4
        #print("Q1,Q2",Q1,Q2)
        return Q1,Q2
    
    #输入参数为屏幕角度，不考虑电机面对面放置
    def scrdraw(self,angle1,angle2):
        #电机02
        self.m02.drawrelative(angle2)
        #杆02
        self.ml02.setangle(angle2)
        self.ml02.draw()
        #电机01放在杆02的右端
        self.m01.setcenter(self.ml02.rightend)
        self.m01.startangle=180+self.m02.angle
        if angle1<=0:
            angle1=0
        self.m01.drawrelative(angle1)
        #杆01固定在电机01中心，角度与电机01一样
        self.ml01.setjointpoint(self.m01.center)
        self.ml01.setangle(self.m01.angle)
        self.ml01.draw()
        self.ml01.drawrightend()
        #杆03永远保持垂直，中心点位于杆01右端下方
        self.ml03.setangle(90)
        L=int(self.ml03.width/2)
        self.ml03.center=np.add(self.ml01.rightend,(0,L))
        self.ml03.draw()
        self.ml03.drawrightend()
        if self.ser is not None:
            cv2.circle(img,(50,50),10,(0,255,0),3)
        else:
            cv2.circle(img,(50,50),10,(0,0,255),3)
        
    #输入角度考虑电机是否对面装配，然后画在图上   
    def robodraw(self,angle1,angle2):
        mangle1=angle1
        mangle2=angle2
        if self.m01.facetome == True:
            print("facetome")
            mangle1=self.m01.maxangle-angle1
        if self.m02.facetome == True:
            mangle2=slef.m02.maxangle-angle2
        print("mangle1,mangle2",mangle1,mangle2)
        self.scrdraw(mangle1,mangle2)
        
    def drawpwm(self,pwm1,pwm2):
        angle1disp=int((pwm1-500)/2000*180)
        angle2disp=int((pwm2-500)/2000*180)
        angel1=int(angle1disp*self.m01.maxangle/180)
        angel2=int(angle2disp*self.m02.maxangle/180)
        
        A1=180+50-(angel1+angel2)
        print("angle1disp,angle2disp,A1,%x,%x,"%(pwm1,pwm2),angle1disp,angle2disp,A1)
        self.robodraw(A1,angel2)
    def xytopwm(self,x,y):
        q1,q2=self.xytoq(x,y)
        # q1=180+50-(q2+pwmq1)
        pwmq1=180+50-(q1+q2)
        pwmq2=q2
        pwm1=int(pwmq1/180*2000+500)
        pwm2=int(pwmq2/180*2000+500)
        return pwm1,pwm2
    
    def serwrite(self,pwm1,pwm2):
        if self.ser is None:
            return
        print(pwm1,pwm2)
        pw1str="%04x"%pwm1
        pw2str="%04x"%pwm2
        print(pw1str,pw2str)
        mo1hexstr="ff 02 01"+" "+pw1str[2:4]+" "+pw1str[0:2]
        mo2hexstr="ff 02 02"+" "+pw2str[2:4]+" "+pw2str[0:2]
        self.ser.write(bytes.fromhex(mo1hexstr))
        self.ser.write(bytes.fromhex(mo2hexstr))
        return
    
    def robotTwin(self,x,y):
        pwm1,pwm2=self.xytopwm(x,y)
        self.drawpwm(pwm1,pwm2)
        self.serwrite(pwm1,pwm2)
        
#配置零件舵机
mM02=mmotor((260+400,360),0,0,180)
mM01=mmotor((0,0),0,0,180)
mM03=mmotor((0,0),0,0,180)
#配置零件梁
mMl01=mlever((0,0),300,20,0)
mMl02=mlever((0,0),300,20,0)
mMl03=mlever((0,0),100,20,0)
#组装成机械臂
marm=Marm(mM01,mM02,mM03,mMl01,mMl02,mMl03)

for i in range(60):
    x=i*10
    y=0
    marm.robotTwin(x,y)
    cv2.imshow("marm",img)
    if cv2.waitKey(100)&0xff == 27:
        break
    #恢复背景
    img=imgcon.copy()

for i in range(60):
    x=600-i*10
    y=0
    marm.robotTwin(x,y)
    cv2.imshow("marm",img)
    if cv2.waitKey(100)&0xff == 27:
        break
    #恢复背景
    img=imgcon.copy()
    
marm.ser.close()
cv2.destroyAllWindows()
# Out:
# (1080, 1440, 3)
# 720 540
# (540, 1120, 3)
# [<serial.tools.list_ports_common.ListPortInfo object at 0x000001B15B4A30F0>]
# USB-SERIAL CH340 (COM7)
# Serial<id=0x1b15b4a3198, open=True>(port='COM7', baudrate=9600, bytesize=8, parity='N', stopbits=1, timeout=None, xonxoff=False, rtscts=False, dsrdtr=False)
# serial conected
# angle1disp,angle2disp,A1,807,5db, 139 89 2
# mangle1,mangle2 2 89
# 2055 1499
# 0807 05db
# angle1disp,angle2disp,A1,7fc,5d1, 138 89 3
# mangle1,mangle2 3 89
# 2044 1489
# 07fc 05d1
# angle1disp,angle2disp,A1,7f2,5c6, 138 88 4
# mangle1,mangle2 4 88
# 2034 1478
# 07f2 05c6
# angle1disp,angle2disp,A1,7e7,5bc, 137 87 6
# mangle1,mangle2 6 87
# 2023 1468
# 07e7 05bc
# angle1disp,angle2disp,A1,7dd,5b1, 136 86 8
# mangle1,mangle2 8 86
# 2013 1457
# 07dd 05b1
# angle1disp,angle2disp,A1,7d2,5a6, 135 85 10
# mangle1,mangle2 10 85
# 2002 1446
# 07d2 05a6
# angle1disp,angle2disp,A1,7c7,59c, 134 84 12
# mangle1,mangle2 12 84
# 1991 1436
# 07c7 059c
# angle1disp,angle2disp,A1,7bd,591, 133 83 14
# mangle1,mangle2 14 83
# 1981 1425
# 07bd 0591
# angle1disp,angle2disp,A1,7b2,586, 132 82 16
# mangle1,mangle2 16 82
# 1970 1414
# 07b2 0586
# angle1disp,angle2disp,A1,7a7,57c, 131 81 18
# mangle1,mangle2 18 81
# 1959 1404
# 07a7 057c
# angle1disp,angle2disp,A1,79c,571, 130 80 20
# mangle1,mangle2 20 80
# 1948 1393
# 079c 0571
# angle1disp,angle2disp,A1,792,566, 129 79 22
# mangle1,mangle2 22 79
# 1938 1382
# 0792 0566
# angle1disp,angle2disp,A1,787,55b, 128 78 24
# mangle1,mangle2 24 78
# 1927 1371
# 0787 055b
# angle1disp,angle2disp,A1,77c,550, 127 77 26
# mangle1,mangle2 26 77
# 1916 1360
# 077c 0550
# angle1disp,angle2disp,A1,771,546, 126 76 28
# mangle1,mangle2 28 76
# 1905 1350
# 0771 0546
# angle1disp,angle2disp,A1,766,53b, 125 75 30
# mangle1,mangle2 30 75
# 1894 1339
# 0766 053b
# angle1disp,angle2disp,A1,75b,530, 124 74 32
# mangle1,mangle2 32 74
# 1883 1328
# 075b 0530
# angle1disp,angle2disp,A1,750,525, 123 73 34
# mangle1,mangle2 34 73
# 1872 1317
# 0750 0525
# angle1disp,angle2disp,A1,745,51a, 122 72 36
# mangle1,mangle2 36 72
# 1861 1306
# 0745 051a
# angle1disp,angle2disp,A1,73a,50e, 121 71 38
# mangle1,mangle2 38 71
# 1850 1294
# 073a 050e
# angle1disp,angle2disp,A1,72f,503, 120 70 40
# mangle1,mangle2 40 70
# 1839 1283
# 072f 0503
# angle1disp,angle2disp,A1,723,4f8, 119 69 42
# mangle1,mangle2 42 69
# 1827 1272
# 0723 04f8
# angle1disp,angle2disp,A1,718,4ec, 118 68 44
# mangle1,mangle2 44 68
# 1816 1260
# 0718 04ec
# angle1disp,angle2disp,A1,70d,4e1, 117 67 46
# mangle1,mangle2 46 67
# 1805 1249
# 070d 04e1
# angle1disp,angle2disp,A1,701,4d6, 116 66 48
# mangle1,mangle2 48 66
# 1793 1238
# 0701 04d6
# angle1disp,angle2disp,A1,6f5,4ca, 115 65 50
# mangle1,mangle2 50 65
# 1781 1226
# 06f5 04ca
# angle1disp,angle2disp,A1,6ea,4be, 114 64 52
# mangle1,mangle2 52 64
# 1770 1214
# 06ea 04be
# angle1disp,angle2disp,A1,6de,4b2, 113 63 54
# mangle1,mangle2 54 63
# 1758 1202
# 06de 04b2
# angle1disp,angle2disp,A1,6d2,4a6, 112 62 56
# mangle1,mangle2 56 62
# 1746 1190
# 06d2 04a6
# angle1disp,angle2disp,A1,6c6,49a, 111 61 58
# mangle1,mangle2 58 61
# 1734 1178
# 06c6 049a
# angle1disp,angle2disp,A1,6ba,48e, 109 59 62
# mangle1,mangle2 62 59
# 1722 1166
# 06ba 048e
# angle1disp,angle2disp,A1,6ad,482, 108 58 64
# mangle1,mangle2 64 58
# 1709 1154
# 06ad 0482
# angle1disp,angle2disp,A1,6a1,475, 107 57 66
# mangle1,mangle2 66 57
# 1697 1141
# 06a1 0475
# angle1disp,angle2disp,A1,694,469, 106 56 68
# mangle1,mangle2 68 56
# 1684 1129
# 0694 0469
# angle1disp,angle2disp,A1,688,45c, 105 55 70
# mangle1,mangle2 70 55
# 1672 1116
# 0688 045c
# angle1disp,angle2disp,A1,67b,44f, 104 54 72
# mangle1,mangle2 72 54
# 1659 1103
# 067b 044f
# angle1disp,angle2disp,A1,66d,442, 103 53 74
# mangle1,mangle2 74 53
# 1645 1090
# 066d 0442
# angle1disp,angle2disp,A1,660,434, 101 51 78
# mangle1,mangle2 78 51
# 1632 1076
# 0660 0434
# angle1disp,angle2disp,A1,652,427, 100 50 80
# mangle1,mangle2 80 50
# 1618 1063
# 0652 0427
# angle1disp,angle2disp,A1,645,419, 99 49 82
# mangle1,mangle2 82 49
# 1605 1049
# 0645 0419
# angle1disp,angle2disp,A1,636,40b, 98 48 84
# mangle1,mangle2 84 48
# 1590 1035
# 0636 040b
# angle1disp,angle2disp,A1,628,3fd, 96 46 88
# mangle1,mangle2 88 46
# 1576 1021
# 0628 03fd
# angle1disp,angle2disp,A1,619,3ee, 95 45 90
# mangle1,mangle2 90 45
# 1561 1006
# 0619 03ee
# angle1disp,angle2disp,A1,60a,3df, 94 44 92
# mangle1,mangle2 92 44
# 1546 991
# 060a 03df
# angle1disp,angle2disp,A1,5fb,3cf, 92 42 96
# mangle1,mangle2 96 42
# 1531 975
# 05fb 03cf
# angle1disp,angle2disp,A1,5eb,3c0, 91 41 98
# mangle1,mangle2 98 41
# 1515 960
# 05eb 03c0
# angle1disp,angle2disp,A1,5db,3af, 89 39 102
# mangle1,mangle2 102 39
# 1499 943
# 05db 03af
# angle1disp,angle2disp,A1,5ca,39f, 88 38 104
# mangle1,mangle2 104 38
# 1482 927
# 05ca 039f
# angle1disp,angle2disp,A1,5b9,38d, 86 36 108
# mangle1,mangle2 108 36
# 1465 909
# 05b9 038d
# angle1disp,angle2disp,A1,5a7,37b, 85 35 110
# mangle1,mangle2 110 35
# 1447 891
# 05a7 037b
# angle1disp,angle2disp,A1,594,368, 83 33 114
# mangle1,mangle2 114 33
# 1428 872
# 0594 0368
# angle1disp,angle2disp,A1,580,355, 81 31 118
# mangle1,mangle2 118 31
# 1408 853
# 0580 0355
# angle1disp,angle2disp,A1,56c,340, 79 29 122
# mangle1,mangle2 122 29
# 1388 832
# 056c 0340
# angle1disp,angle2disp,A1,556,32a, 77 27 126
# mangle1,mangle2 126 27
# 1366 810
# 0556 032a
# angle1disp,angle2disp,A1,53e,313, 75 25 130
# mangle1,mangle2 130 25
# 1342 787
# 053e 0313
# angle1disp,angle2disp,A1,525,2f9, 73 23 134
# mangle1,mangle2 134 23
# 1317 761
# 0525 02f9
# angle1disp,angle2disp,A1,509,2dd, 71 20 139
# mangle1,mangle2 139 20
# 1289 733
# 0509 02dd
# angle1disp,angle2disp,A1,4e9,2be, 68 18 144
# mangle1,mangle2 144 18
# 1257 702
# 04e9 02be
# angle1disp,angle2disp,A1,4c4,298, 64 14 152
# mangle1,mangle2 152 14
# 1220 664
# 04c4 0298
# angle1disp,angle2disp,A1,493,268, 60 10 160
# mangle1,mangle2 160 10
# 1171 616
# 0493 0268
# angle1disp,angle2disp,A1,469,23d, 56 6 168
# mangle1,mangle2 168 6
# 1129 573
# 0469 023d
# angle1disp,angle2disp,A1,493,268, 60 10 160
# mangle1,mangle2 160 10
# 1171 616
# 0493 0268
# angle1disp,angle2disp,A1,4c4,298, 64 14 152
# mangle1,mangle2 152 14
# 1220 664
# 04c4 0298
# angle1disp,angle2disp,A1,4e9,2be, 68 18 144
# mangle1,mangle2 144 18
# 1257 702
# 04e9 02be
# angle1disp,angle2disp,A1,509,2dd, 71 20 139
# mangle1,mangle2 139 20
# 1289 733
# 0509 02dd
# angle1disp,angle2disp,A1,525,2f9, 73 23 134
# mangle1,mangle2 134 23
# 1317 761
# 0525 02f9
# angle1disp,angle2disp,A1,53e,313, 75 25 130
# mangle1,mangle2 130 25
# 1342 787
# 053e 0313
# angle1disp,angle2disp,A1,556,32a, 77 27 126
# mangle1,mangle2 126 27
# 1366 810
# 0556 032a
# angle1disp,angle2disp,A1,56c,340, 79 29 122
# mangle1,mangle2 122 29
# 1388 832
# 056c 0340
# angle1disp,angle2disp,A1,580,355, 81 31 118
# mangle1,mangle2 118 31
# 1408 853
# 0580 0355
# angle1disp,angle2disp,A1,594,368, 83 33 114
# mangle1,mangle2 114 33
# 1428 872
# 0594 0368
# angle1disp,angle2disp,A1,5a7,37b, 85 35 110
# mangle1,mangle2 110 35
# 1447 891
# 05a7 037b
# angle1disp,angle2disp,A1,5b9,38d, 86 36 108
# mangle1,mangle2 108 36
# 1465 909
# 05b9 038d
# angle1disp,angle2disp,A1,5ca,39f, 88 38 104
# mangle1,mangle2 104 38
# 1482 927
# 05ca 039f
# angle1disp,angle2disp,A1,5db,3af, 89 39 102
# mangle1,mangle2 102 39
# 1499 943
# 05db 03af
# angle1disp,angle2disp,A1,5eb,3c0, 91 41 98
# mangle1,mangle2 98 41
# 1515 960
# 05eb 03c0
# angle1disp,angle2disp,A1,5fb,3cf, 92 42 96
# mangle1,mangle2 96 42
# 1531 975
# 05fb 03cf
# angle1disp,angle2disp,A1,60a,3df, 94 44 92
# mangle1,mangle2 92 44
# 1546 991
# 060a 03df
# angle1disp,angle2disp,A1,619,3ee, 95 45 90
# mangle1,mangle2 90 45
# 1561 1006
# 0619 03ee
# angle1disp,angle2disp,A1,628,3fd, 96 46 88
# mangle1,mangle2 88 46
# 1576 1021
# 0628 03fd
# angle1disp,angle2disp,A1,636,40b, 98 48 84
# mangle1,mangle2 84 48
# 1590 1035
# 0636 040b
# angle1disp,angle2disp,A1,645,419, 99 49 82
# mangle1,mangle2 82 49
# 1605 1049
# 0645 0419
# angle1disp,angle2disp,A1,652,427, 100 50 80
# mangle1,mangle2 80 50
# 1618 1063
# 0652 0427
# angle1disp,angle2disp,A1,660,434, 101 51 78
# mangle1,mangle2 78 51
# 1632 1076
# 0660 0434
# angle1disp,angle2disp,A1,66d,442, 103 53 74
# mangle1,mangle2 74 53
# 1645 1090
# 066d 0442
# angle1disp,angle2disp,A1,67b,44f, 104 54 72
# mangle1,mangle2 72 54
# 1659 1103
# 067b 044f
# angle1disp,angle2disp,A1,688,45c, 105 55 70
# mangle1,mangle2 70 55
# 1672 1116
# 0688 045c
# angle1disp,angle2disp,A1,694,469, 106 56 68
# mangle1,mangle2 68 56
# 1684 1129
# 0694 0469
# angle1disp,angle2disp,A1,6a1,475, 107 57 66
# mangle1,mangle2 66 57
# 1697 1141
# 06a1 0475
# angle1disp,angle2disp,A1,6ad,482, 108 58 64
# mangle1,mangle2 64 58
# 1709 1154
# 06ad 0482
# angle1disp,angle2disp,A1,6ba,48e, 109 59 62
# mangle1,mangle2 62 59
# 1722 1166
# 06ba 048e
# angle1disp,angle2disp,A1,6c6,49a, 111 61 58
# mangle1,mangle2 58 61
# 1734 1178
# 06c6 049a
# angle1disp,angle2disp,A1,6d2,4a6, 112 62 56
# mangle1,mangle2 56 62
# 1746 1190
# 06d2 04a6
# angle1disp,angle2disp,A1,6de,4b2, 113 63 54
# mangle1,mangle2 54 63
# 1758 1202
# 06de 04b2
# angle1disp,angle2disp,A1,6ea,4be, 114 64 52
# mangle1,mangle2 52 64
# 1770 1214
# 06ea 04be
# angle1disp,angle2disp,A1,6f5,4ca, 115 65 50
# mangle1,mangle2 50 65
# 1781 1226
# 06f5 04ca
# angle1disp,angle2disp,A1,701,4d6, 116 66 48
# mangle1,mangle2 48 66
# 1793 1238
# 0701 04d6
# angle1disp,angle2disp,A1,70d,4e1, 117 67 46
# mangle1,mangle2 46 67
# 1805 1249
# 070d 04e1
# angle1disp,angle2disp,A1,718,4ec, 118 68 44
# mangle1,mangle2 44 68
# 1816 1260
# 0718 04ec
# angle1disp,angle2disp,A1,723,4f8, 119 69 42
# mangle1,mangle2 42 69
# 1827 1272
# 0723 04f8
# angle1disp,angle2disp,A1,72f,503, 120 70 40
# mangle1,mangle2 40 70
# 1839 1283
# 072f 0503
# angle1disp,angle2disp,A1,73a,50e, 121 71 38
# mangle1,mangle2 38 71
# 1850 1294
# 073a 050e
# angle1disp,angle2disp,A1,745,51a, 122 72 36
# mangle1,mangle2 36 72
# 1861 1306
# 0745 051a
# angle1disp,angle2disp,A1,750,525, 123 73 34
# mangle1,mangle2 34 73
# 1872 1317
# 0750 0525
# angle1disp,angle2disp,A1,75b,530, 124 74 32
# mangle1,mangle2 32 74
# 1883 1328
# 075b 0530
# angle1disp,angle2disp,A1,766,53b, 125 75 30
# mangle1,mangle2 30 75
# 1894 1339
# 0766 053b
# angle1disp,angle2disp,A1,771,546, 126 76 28
# mangle1,mangle2 28 76
# 1905 1350
# 0771 0546
# angle1disp,angle2disp,A1,77c,550, 127 77 26
# mangle1,mangle2 26 77
# 1916 1360
# 077c 0550
# angle1disp,angle2disp,A1,787,55b, 128 78 24
# mangle1,mangle2 24 78
# 1927 1371
# 0787 055b
# angle1disp,angle2disp,A1,792,566, 129 79 22
# mangle1,mangle2 22 79
# 1938 1382
# 0792 0566
# angle1disp,angle2disp,A1,79c,571, 130 80 20
# mangle1,mangle2 20 80
# 1948 1393
# 079c 0571
# angle1disp,angle2disp,A1,7a7,57c, 131 81 18
# mangle1,mangle2 18 81
# 1959 1404
# 07a7 057c
# angle1disp,angle2disp,A1,7b2,586, 132 82 16
# mangle1,mangle2 16 82
# 1970 1414
# 07b2 0586
# angle1disp,angle2disp,A1,7bd,591, 133 83 14
# mangle1,mangle2 14 83
# 1981 1425
# 07bd 0591
# angle1disp,angle2disp,A1,7c7,59c, 134 84 12
# mangle1,mangle2 12 84
# 1991 1436
# 07c7 059c
# angle1disp,angle2disp,A1,7d2,5a6, 135 85 10
# mangle1,mangle2 10 85
# 2002 1446
# 07d2 05a6
# angle1disp,angle2disp,A1,7dd,5b1, 136 86 8
# mangle1,mangle2 8 86
# 2013 1457
# 07dd 05b1
# angle1disp,angle2disp,A1,7e7,5bc, 137 87 6
# mangle1,mangle2 6 87
# 2023 1468
# 07e7 05bc
# angle1disp,angle2disp,A1,7f2,5c6, 138 88 4
# mangle1,mangle2 4 88
# 2034 1478
# 07f2 05c6
# angle1disp,angle2disp,A1,7fc,5d1, 138 89 3
# mangle1,mangle2 3 89
# 2044 1489
# 07fc 05d1

# %%
import cv2
import numpy as np
import math  as mt

img=cv2.imread("marm.jpg")
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
print(W,H)
img=cv2.resize(img,(W,H))
imgcon=img.copy()
print(img.shape)

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            print("caculate center")
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            print(w,h)
            self.center=self.jointpoint-np.array([w,h])
            print(self.center)    
        rect=(self.center, (self.width,self.height), self.angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)          
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjoitpoint(self,jointpoint):
        self.jointpoint=jointpoint
        
ml02=mlever((400,200),100,10,0)
ml02.setjoitpoint((270,370))

for i in range(12):
    ml02.setangle(i*30)
    ml02.draw()
    cv2.imshow("marm",img)
    cv2.waitKey(1000)
    #恢复背景
    img=imgcon.copy()
cv2.destroyAllWindows()
# Out:
# (1080, 1440, 3)
# 720 540
# (540, 720, 3)
# caculate center
# 50 0
# [220 370]
# caculate center
# 43 24
# [227 346]
# caculate center
# 25 43
# [245 327]
# caculate center
# 0 50
# [270 320]
# caculate center
# -24 43
# [294 327]
# caculate center
# -43 24
# [313 346]
# caculate center
# -50 0
# [320 370]
# caculate center
# -43 -25
# [313 395]
# caculate center
# -25 -43
# [295 413]
# caculate center
# 0 -50
# [270 420]
# caculate center
# 25 -43
# [245 413]
# caculate center
# 43 -25
# [227 395]

# %%
import cv2
import numpy as np
import math  as mt

img=cv2.imread("marm.jpg")

#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
print(W,H)
img=cv2.resize(img,(W,H))
print(img.shape)

#电机模型
class mmotor():
    def __init__(self,center,angle,fixangle):
        self.center=center
        self.angle=angle
        self.fixangle=fixangle
        
    def setfixangle(self,fixangle):
        self.fixangle=fixangle
        ,
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle+self.fixangle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.rightend=(0,0)
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            print("caculate center")
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            self.center=self.jointpoint-np.array([w,h])
            self.rightend=self.center-np.array([w,h])
            print(self.center)    
        rect=(self.center, (self.width,self.height), self.angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)          
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjoitpoint(self,jointpoint):
        self.jointpoint=jointpoint
        
m02=mmotor((210,120),0,0)
ml02=mlever((0,0),340,20,0)
ml02.setjoitpoint((260,360))
for i in range(18):
    angle=i*10
    m02.draw(angle)
    ml02.setangle(angle)
    ml02.draw()
    cv2.imshow("marm",img)
    cv2.waitKey(1000)
    #恢复背景
    img=imgcon.copy()

cv2.destroyAllWindows()
# Out:
# (1080, 1440, 3)
# 720 540
# (540, 720, 3)
# caculate center
# [ 90 360]
# caculate center
# [ 93 331]
# caculate center
# [101 302]
# caculate center
# [113 276]
# caculate center
# [130 251]
# caculate center
# [151 230]
# caculate center
# [175 213]
# caculate center
# [202 201]
# caculate center
# [231 193]
# caculate center
# [260 190]
# caculate center
# [289 193]
# caculate center
# [318 201]
# caculate center
# [344 213]
# caculate center
# [369 230]
# caculate center
# [390 251]
# caculate center
# [407 276]
# caculate center
# [419 302]
# caculate center
# [427 331]

# %%
import cv2
import numpy as np
import math  as mt
import serial
import serial.tools.list_ports
import string
import binascii
import time


img=cv2.imread("marm.jpg")
#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
BW=int(W*1.5)+1
print(W,H)
img=cv2.resize(img,(W,H))
img= cv2.copyMakeBorder(img,0,0,400,0,cv2.BORDER_CONSTANT,value=(100,100,0))
imgcon=img.copy()
print(img.shape)

#电机模型
class mmotor():
    def __init__(self,center,angle,startangle,maxangle):
        self.center=center
        self.angle=angle
        self.startangle=startangle
        self.maxangle=maxangle
        self.relaangle=0
        self.pwm=500
        self.facetome=False
        
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        self.angle=angle
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)
    def drawrelative(self,relaangle):
        if relaangle >self.maxangle:
            relaangle=self.maxangle
        self.relaangle=relaangle
        self.angle=self.startangle+self.relaangle
        self.pwm=500+self.relaangle*180/self.maxangle*(2500-500)/180
        self.draw(self.angle)
        

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.rightend=(width,0)
        self.rightendr=10
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            self.center=(self.jointpoint[0]-w,self.jointpoint[1]-h)
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(self.jointpoint[0]-w*2,self.jointpoint[1]-h*2)
        else:
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(int((box[2][0]+box[3][0])/2),int((box[2][1]+box[3][1])/2))
        cv2.drawContours(img,[box],0,(255,0,0),3)          
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjointpoint(self,jointpoint):
        self.jointpoint=jointpoint
    def drawrightend(self):
        cv2.circle(img,self.rightend,self.rightendr,(0,0,255),3)

class Marm():
    def __init__(self,m01,m02,m03,ml01,ml02,ml03):
        self.m01=m01
        self.m02=m02
        self.m03=m03        
        self.ml01=ml01
        self.ml02=ml02
        self.ml03=ml03 
        self.angle1=0
        self.angle2=0
        self.angle3=0
        self.ser=None
        #将梁2固定在电机2的中心
        self.ml02.setjointpoint(self.m02.center)
        #打开串口
        ports = list(serial.tools.list_ports.comports())
        print (ports)
        #便利 寻找串口
        for p in ports:
            print (p[1])
            if "serial" in p[1] or "CH340" in p[1]:
                self.ser=serial.Serial(port=p[0])
                if self.ser is not None:
                    print(self.ser)
                    print("serial conected")
                else:
                    print("serial not connected")
                    return
            else:
                print ("No CH340 Device was found connected to the computer")
                return
        self.robotinit()
    def robotinit(self):
        if self.ser is None:
            return
        m0=bytes.fromhex('ff 01 00 08 00')# 舵机0速度为 72
        m1=bytes.fromhex('ff 01 01 08 00')# 舵机1速度为 72
        m2=bytes.fromhex('ff 01 02 08 00')# 舵机2速度为 72
        mo0=bytes.fromhex('ff 02 00 dc 05')#设置初始舵机0位置
        mo1=bytes.fromhex('ff 02 01 82 07')#设置初始舵机1的位置
        mo2 = bytes.fromhex('ff 02 02 dc 05')#设置初始舵机2的位置
        mo3 = bytes.fromhex('ff 02 03 dc 05')#设置初始舵机3的位置
        self.ser.write(m0)
        self.ser.write(m1)
        self.ser.write(m2)
        self.ser.write(mo0)
        self.ser.write(mo1)
        self.ser.write(mo2)
        self.ser.write(mo3)
    def xytoq(self,x,y):
        L1=self.ml01.width
        L2=self.ml02.width
        L3=mt.sqrt(y*y+x*x)+0.01
        #L3最长不超过两臂之和
        if L3>L1+L2:
            L3=L1+L2-4
        #L3最短不少于两臂之差
        if L3<abs(L1-L2):
            L3=abs(L1-L2)+4
        p=(L1+L2+L3)/2
        S=mt.sqrt(p*(p-L1)*(p-L2)*(p-L3))
        h=S*2/L3
        Q5=mt.asin(h/L2)/mt.pi*180
        Q4=mt.asin(y/L3)/mt.pi*180
        Q7=mt.asin(h/L1)/mt.pi*180
        Q1=180-Q5-Q7
        Q2=Q5+Q4
        #print("Q1,Q2",Q1,Q2)
        return Q1,Q2
    
    #输入参数为屏幕角度，不考虑电机面对面放置
    def scrdraw(self,angle1,angle2):
        #电机02
        self.m02.drawrelative(angle2)
        #杆02
        self.ml02.setangle(angle2)
        self.ml02.draw()
        #电机01放在杆02的右端
        self.m01.setcenter(self.ml02.rightend)
        self.m01.startangle=180+self.m02.angle
        if angle1<=0:
            angle1=0
        self.m01.drawrelative(angle1)
        #杆01固定在电机01中心，角度与电机01一样
        self.ml01.setjointpoint(self.m01.center)
        self.ml01.setangle(self.m01.angle)
        self.ml01.draw()
        self.ml01.drawrightend()
        #杆03永远保持垂直，中心点位于杆01右端下方
        self.ml03.setangle(90)
        L=int(self.ml03.width/2)
        self.ml03.center=np.add(self.ml01.rightend,(0,L))
        self.ml03.draw()
        self.ml03.drawrightend()
        if self.ser is not None:
            cv2.circle(img,(50,50),10,(0,255,0),3)
        else:
            cv2.circle(img,(50,50),10,(0,0,255),3)
        
    #输入角度考虑电机是否对面装配，然后画在图上   
    def robodraw(self,angle1,angle2):
        mangle1=angle1
        mangle2=angle2
        if self.m01.facetome == True:
            print("facetome")
            mangle1=self.m01.maxangle-angle1
        if self.m02.facetome == True:
            mangle2=slef.m02.maxangle-angle2
        print("mangle1,mangle2",mangle1,mangle2)
        self.scrdraw(mangle1,mangle2)
        
    def drawpwm(self,pwm1,pwm2):
        angle1disp=int((pwm1-500)/2000*180)
        angle2disp=int((pwm2-500)/2000*180)
        angel1=int(angle1disp*self.m01.maxangle/180)
        angel2=int(angle2disp*self.m02.maxangle/180)
        
        A1=180+50-(angel1+angel2)
        print("angle1disp,angle2disp,A1,%x,%x,"%(pwm1,pwm2),angle1disp,angle2disp,A1)
        self.robodraw(A1,angel2)
    def xytopwm(self,x,y):
        q1,q2=self.xytoq(x,y)
        # q1=180+50-(q2+pwmq1)
        pwmq1=180+50-(q1+q2)
        pwmq2=q2
        pwm1=int(pwmq1/180*2000+500)
        pwm2=int(pwmq2/180*2000+500)
        return pwm1,pwm2
    
    def serwrite(self,pwm1,pwm2):
        if self.ser is None:
            return
        print(pwm1,pwm2)
        pw1str="%04x"%pwm1
        pw2str="%04x"%pwm2
        print(pw1str,pw2str)
        mo1hexstr="ff 02 01"+" "+pw1str[2:4]+" "+pw1str[0:2]
        mo2hexstr="ff 02 02"+" "+pw2str[2:4]+" "+pw2str[0:2]
        self.ser.write(bytes.fromhex(mo1hexstr))
        self.ser.write(bytes.fromhex(mo2hexstr))
        return
    
    def robotTwin(self,x,y):
        pwm1,pwm2=self.xytopwm(x,y)
        self.drawpwm(pwm1,pwm2)
        self.serwrite(pwm1,pwm2)
        
#配置零件舵机
mM02=mmotor((260+400,360),0,0,180)
mM01=mmotor((0,0),0,0,180)
mM03=mmotor((0,0),0,0,180)
#配置零件梁
mMl01=mlever((0,0),300,20,0)
mMl02=mlever((0,0),300,20,0)
mMl03=mlever((0,0),100,20,0)
#组装成机械臂
marm=Marm(mM01,mM02,mM03,mMl01,mMl02,mMl03)

for i in range(60):
    x=i*10
    y=0
    marm.robotTwin(x,y)
    cv2.imshow("marm",img)
    if cv2.waitKey(100)&0xff == 27:
        break
    #恢复背景
    img=imgcon.copy()

'''for i in range(60):
    x=600-i*10
    y=0
    marm.robotTwin(x,y)
    cv2.imshow("marm",img)
    if cv2.waitKey(100)&0xff == 27:
        break
    #恢复背景
    img=imgcon.copy()
    '''
marm.ser.close()
cv2.destroyAllWindows()
# Out:
# (1080, 1440, 3)
# 720 540
# (540, 1120, 3)
# []
# angle1disp,angle2disp,A1,807,5db, 139 89 2
# mangle1,mangle2 2 89
# angle1disp,angle2disp,A1,7fc,5d1, 138 89 3
# mangle1,mangle2 3 89
# angle1disp,angle2disp,A1,7f2,5c6, 138 88 4
# mangle1,mangle2 4 88
# angle1disp,angle2disp,A1,7e7,5bc, 137 87 6
# mangle1,mangle2 6 87
# angle1disp,angle2disp,A1,7dd,5b1, 136 86 8
# mangle1,mangle2 8 86
# angle1disp,angle2disp,A1,7d2,5a6, 135 85 10
# mangle1,mangle2 10 85
# angle1disp,angle2disp,A1,7c7,59c, 134 84 12
# mangle1,mangle2 12 84
# angle1disp,angle2disp,A1,7bd,591, 133 83 14
# mangle1,mangle2 14 83
# angle1disp,angle2disp,A1,7b2,586, 132 82 16
# mangle1,mangle2 16 82
# angle1disp,angle2disp,A1,7a7,57c, 131 81 18
# mangle1,mangle2 18 81
# angle1disp,angle2disp,A1,79c,571, 130 80 20
# mangle1,mangle2 20 80
# angle1disp,angle2disp,A1,792,566, 129 79 22
# mangle1,mangle2 22 79
# angle1disp,angle2disp,A1,787,55b, 128 78 24
# mangle1,mangle2 24 78
# angle1disp,angle2disp,A1,77c,550, 127 77 26
# mangle1,mangle2 26 77
# angle1disp,angle2disp,A1,771,546, 126 76 28
# mangle1,mangle2 28 76
# angle1disp,angle2disp,A1,766,53b, 125 75 30
# mangle1,mangle2 30 75
# angle1disp,angle2disp,A1,75b,530, 124 74 32
# mangle1,mangle2 32 74
# angle1disp,angle2disp,A1,750,525, 123 73 34
# mangle1,mangle2 34 73
# angle1disp,angle2disp,A1,745,51a, 122 72 36
# mangle1,mangle2 36 72
# angle1disp,angle2disp,A1,73a,50e, 121 71 38
# mangle1,mangle2 38 71
# angle1disp,angle2disp,A1,72f,503, 120 70 40
# mangle1,mangle2 40 70
# angle1disp,angle2disp,A1,723,4f8, 119 69 42
# mangle1,mangle2 42 69
# angle1disp,angle2disp,A1,718,4ec, 118 68 44
# mangle1,mangle2 44 68
# angle1disp,angle2disp,A1,70d,4e1, 117 67 46
# mangle1,mangle2 46 67
# angle1disp,angle2disp,A1,701,4d6, 116 66 48
# mangle1,mangle2 48 66
# angle1disp,angle2disp,A1,6f5,4ca, 115 65 50
# mangle1,mangle2 50 65
# angle1disp,angle2disp,A1,6ea,4be, 114 64 52
# mangle1,mangle2 52 64
# angle1disp,angle2disp,A1,6de,4b2, 113 63 54
# mangle1,mangle2 54 63
# angle1disp,angle2disp,A1,6d2,4a6, 112 62 56
# mangle1,mangle2 56 62
# angle1disp,angle2disp,A1,6c6,49a, 111 61 58
# mangle1,mangle2 58 61
# angle1disp,angle2disp,A1,6ba,48e, 109 59 62
# mangle1,mangle2 62 59
# angle1disp,angle2disp,A1,6ad,482, 108 58 64
# mangle1,mangle2 64 58
# angle1disp,angle2disp,A1,6a1,475, 107 57 66
# mangle1,mangle2 66 57
# angle1disp,angle2disp,A1,694,469, 106 56 68
# mangle1,mangle2 68 56
# angle1disp,angle2disp,A1,688,45c, 105 55 70
# mangle1,mangle2 70 55
# angle1disp,angle2disp,A1,67b,44f, 104 54 72
# mangle1,mangle2 72 54
# angle1disp,angle2disp,A1,66d,442, 103 53 74
# mangle1,mangle2 74 53
# angle1disp,angle2disp,A1,660,434, 101 51 78
# mangle1,mangle2 78 51
# angle1disp,angle2disp,A1,652,427, 100 50 80
# mangle1,mangle2 80 50
# angle1disp,angle2disp,A1,645,419, 99 49 82
# mangle1,mangle2 82 49
# angle1disp,angle2disp,A1,636,40b, 98 48 84
# mangle1,mangle2 84 48
# angle1disp,angle2disp,A1,628,3fd, 96 46 88
# mangle1,mangle2 88 46
# angle1disp,angle2disp,A1,619,3ee, 95 45 90
# mangle1,mangle2 90 45
# angle1disp,angle2disp,A1,60a,3df, 94 44 92
# mangle1,mangle2 92 44
# angle1disp,angle2disp,A1,5fb,3cf, 92 42 96
# mangle1,mangle2 96 42
# angle1disp,angle2disp,A1,5eb,3c0, 91 41 98
# mangle1,mangle2 98 41
# angle1disp,angle2disp,A1,5db,3af, 89 39 102
# mangle1,mangle2 102 39
# angle1disp,angle2disp,A1,5ca,39f, 88 38 104
# mangle1,mangle2 104 38
# angle1disp,angle2disp,A1,5b9,38d, 86 36 108
# mangle1,mangle2 108 36
# angle1disp,angle2disp,A1,5a7,37b, 85 35 110
# mangle1,mangle2 110 35
# angle1disp,angle2disp,A1,594,368, 83 33 114
# mangle1,mangle2 114 33
# angle1disp,angle2disp,A1,580,355, 81 31 118
# mangle1,mangle2 118 31
# angle1disp,angle2disp,A1,56c,340, 79 29 122
# mangle1,mangle2 122 29
# angle1disp,angle2disp,A1,556,32a, 77 27 126
# mangle1,mangle2 126 27
# angle1disp,angle2disp,A1,53e,313, 75 25 130
# mangle1,mangle2 130 25
# angle1disp,angle2disp,A1,525,2f9, 73 23 134
# mangle1,mangle2 134 23
# angle1disp,angle2disp,A1,509,2dd, 71 20 139
# mangle1,mangle2 139 20
# angle1disp,angle2disp,A1,4e9,2be, 68 18 144
# mangle1,mangle2 144 18
# angle1disp,angle2disp,A1,4c4,298, 64 14 152
# mangle1,mangle2 152 14
# angle1disp,angle2disp,A1,493,268, 60 10 160
# mangle1,mangle2 160 10
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-784699f6c8b1> in <module>
#     269     img=imgcon.copy()
#     270     '''
# --> 271 marm.ser.close()
#     272 cv2.destroyAllWindows()
#
# AttributeError: 'NoneType' object has no attribute 'close'

# %%
from wordcloud import WordCloud
import jieba

fp=open("lovecn.txt")
text = fp.read()
print(text)
wordlist=jieba.cut(text)
textcn=" ".join(wordlist)
print(textcn)
wordcloud = WordCloud(font_path = "C:\Windows\Fonts\simhei.TTF").generate(textcn)
image_produce = wordcloud.to_image()
image_produce.show()
# Out:
# 我爱你不是因为你是谁，而是因为我和你在一起的时候是谁。
# 没有人值得你流泪，值得让你这么做的人不会让你哭泣。
# 错过别人的最糟糕的方式是坐在他们旁边，知道你不能拥有他们。
# 纵然伤心，也不要皱眉，因为你不知道是谁爱上了你的笑容。
# 对世界而言，你可能是一个人，但对某个人来说，你可能是整个世界
# 不要把你的时间浪费在一个不愿在你身上浪费时间的男人/女人身上。
# 仅仅因为某人没有按你所希望的方式爱你，并不意味着他们没有全心全意地爱你。
# 不要努力，最好的事情总会在你最不期待的时候出现。
# 我爱你 不是 因为 你 是 谁 ， 而是 因为 我 和 你 在 一起 的 时候 是 谁 。
#  没有 人 值得 你 流泪 ， 值得 让 你 这么 做 的 人 不会 让 你 哭泣 。
#  错过 别人 的 最 糟糕 的 方式 是 坐在 他们 旁边 ， 知道 你 不能 拥有 他们 。
#  纵然 伤心 ， 也 不要 皱眉 ， 因为 你 不 知道 是 谁 爱 上 了 你的笑容 。
#  对 世界 而言 ， 你 可能 是 一个 人 ， 但 对 某个 人 来说 ， 你 可能 是 整个 世界
#  不要 把 你 的 时间 浪费 在 一个 不愿 在 你 身上 浪费时间 的 男人 / 女人 身上 。
#  仅仅 因为 某人 没有 按 你 所 希望 的 方式 爱 你 ， 并 不 意味着 他们 没有 全心全意 地爱 你 。
#  不要 努力 ， 最好 的 事情 总会 在 你 最 不 期待 的 时候 出现 。
