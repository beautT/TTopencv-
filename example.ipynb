# %%
import cv2
import numpy as np

img=cv2.imread("marm.jpg")

#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
print(W,H)
img=cv2.resize(img,(W,H))
print(img.shape)

angle=0
circlecenter=(260,360)
color=(0,255,0)
r=30
cv2.circle(img,circlecenter,r,color,5)
rect=(circlecenter,(2*r,4),angle)
box = cv2.boxPoints(rect).astype(np.int0)
cv2.drawContours(img,[box],0,(255,0,0),3)

angle=30
circlecenter=(260,360)
color=(0,255,0)
r=30
cv2.circle(img,circlecenter,r,color,5)
rect=(circlecenter,(2*r,4),angle)
box = cv2.boxPoints(rect).astype(np.int0)
cv2.drawContours(img,[box],0,(255,0,0),3)

angle=90
circlecenter=(260,360)
color=(0,255,0)
r=30
cv2.circle(img,circlecenter,r,color,5)
rect=(circlecenter,(2*r,4),angle)
box = cv2.boxPoints(rect).astype(np.int0)
cv2.drawContours(img,[box],0,(255,0,0),3)

cv2.imshow("img",img)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# (1080, 1440, 3)
# 720 540
# (540, 720, 3)

# %%
import cv2
import numpy as np

img=cv2.imread("marm.jpg")

#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
print(W,H)
img=cv2.resize(img,(W,H))
print(img.shape)

def drawmotor(center,angle):
    color=(0,255,0)
    r=30
    cv2.circle(img,center,r,color,-1)
    rect=(center,(2*r,4),angle)
    box = cv2.boxPoints(rect).astype(np.int0)
    cv2.drawContours(img,[box],0,(255,0,0),3)

center=(260,360)
center1=(500,150)
for i in range(10):
    drawmotor(center,i*30)
    drawmotor(center1,i*30)
    cv2.imshow("img",img)
    cv2.waitKey(1000)

#cv2.imshow("img",img)
#cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# (1080, 1440, 3)
# 720 540
# (540, 720, 3)

# %%
import cv2
import numpy as np

img=cv2.imread("marm.jpg")

#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
print(W,H)
img=cv2.resize(img,(W,H))
print(img.shape)

class mmotor():
    def __init__(self,center,angle,fixangle):
        self.center=center
        self.angle=angle
        self.fixangle=fixangle
        
    def setfixangle(fixangle):
        self.fixangle=fixangle
        
    def setcenter(center):
        self.center=center
        
    def draw(self,angle):
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle+self.fixangle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)

m02=mmotor((260,360),60,180)
#m01=mmotor((500,150),0,-30)
for i in range(30):
    m02.draw(i*10)
    #m01.draw(i*10)
    cv2.imshow("img",img)
    cv2.waitKey(1000)

cv2.destroyAllWindows()
# Out:
# (1080, 1440, 3)
# 720 540
# (540, 720, 3)

# %%
import cv2
import numpy as np
import math  as mt

img=cv2.imread("marm.jpg")
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
print(W,H)
img=cv2.resize(img,(W,H))
imgcon=img.copy()
print(img.shape)

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            print("caculate center")
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            print(w,h)
            self.center=self.jointpoint-np.array([w,h])
            print(self.center)    
        rect=(self.center, (self.width,self.height), self.angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)          
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjoitpoint(self,jointpoint):
        self.jointpoint=jointpoint
        
ml02=mlever((380,245),100,10,0)
ml02.setjoitpoint((270,370))

for i in range(12):
    ml02.setangle(i*30)
    ml02.draw()
    cv2.imshow("marm",img)
    cv2.waitKey(1000)
    #恢复背景
    img=imgcon.copy()
cv2.destroyAllWindows()
# Out:
# (1080, 1440, 3)
# 720 540
# (540, 720, 3)
# caculate center
# 50 0
# [220 370]
# caculate center
# 43 24
# [227 346]
# caculate center
# 25 43
# [245 327]
# caculate center
# 0 50
# [270 320]
# caculate center
# -24 43
# [294 327]
# caculate center
# -43 24
# [313 346]
# caculate center
# -50 0
# [320 370]
# caculate center
# -43 -25
# [313 395]
# caculate center
# -25 -43
# [295 413]
# caculate center
# 0 -50
# [270 420]
# caculate center
# 25 -43
# [245 413]
# caculate center
# 43 -25
# [227 395]

# %%
import cv2
import numpy as np
import math  as mt

img=cv2.imread("marm.jpg")

#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
print(W,H)
img=cv2.resize(img,(W,H))
imgcon=img.copy()
print(img.shape)

#电机模型
class mmotor():
    def __init__(self,center,angle,fixangle):
        self.center=center
        self.angle=angle
        self.fixangle=fixangle
        
    def setfixangle(self,fixangle):
        self.fixangle=fixangle
        ,
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle+self.fixangle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.rightend=(0,0)
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            print("caculate center")
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            self.center=self.jointpoint-np.array([w,h])
            self.rightend=self.center-np.array([w,h])
            print(self.center)    
        rect=(self.center, (self.width,self.height), self.angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)          
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjoitpoint(self,jointpoint):
        self.jointpoint=jointpoint
        
m02=mmotor((260,360),0,0)
ml02=mlever((0,0),340,20,0)
ml02.setjoitpoint((260,360))
for i in range(18):
    angle=i*10
    m02.draw(angle)
    ml02.setangle(angle)
    ml02.draw()
    cv2.imshow("marm",img)
    cv2.waitKey(1000)
    #恢复背景
    img=imgcon.copy()

cv2.destroyAllWindows()
# Out:
# (1080, 1440, 3)
# 720 540
# (540, 720, 3)
# caculate center
# [ 90 360]
# caculate center
# [ 93 331]
# caculate center
# [101 302]
# caculate center
# [113 276]
# caculate center
# [130 251]
# caculate center
# [151 230]
# caculate center
# [175 213]
# caculate center
# [202 201]
# caculate center
# [231 193]
# caculate center
# [260 190]
# caculate center
# [289 193]
# caculate center
# [318 201]
# caculate center
# [344 213]
# caculate center
# [369 230]
# caculate center
# [390 251]
# caculate center
# [407 276]
# caculate center
# [419 302]
# caculate center
# [427 331]

# %%
# Out:
# (1080, 1440, 3)
# 720 540
# (540, 720, 3)
# caculate center
# 50 0
# [220 370]
# caculate center
# 43 24
# [227 346]
# caculate center
# 25 43
# [245 327]
# caculate center
# 0 50
# [270 320]
# caculate center
# -24 43
# [294 327]
# caculate center
# -43 24
# [313 346]
# caculate center
# -50 0
# [320 370]
# caculate center
# -43 -25
# [313 395]
# caculate center
# -25 -43
# [295 413]
# caculate center
# 0 -50
# [270 420]
# caculate center
# 25 -43
# [245 413]
# caculate center
# 43 -25
# [227 395]

# %%
import cv2
import numpy as np
import math  as mt

img=cv2.imread("marm.jpg")
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
print(W,H)
img=cv2.resize(img,(W,H))
imgcon=img.copy()
print(img.shape)

centerm=(260,360)
def drawmotor(centerm,angle):
    color=(0,255,0)
    r=30
    cv2.circle(img,centerm,r,color,5)
    rect=(centerm,(2*r,4),angle)
    box = cv2.boxPoints(rect).astype(np.int0)
    cv2.drawContours(img,[box],0,(255,0,0),3)

joitpoint=(260,360)
centerl=(0,0)
widthl=340
highl=20
#中心点，长度，角度
def drawlever(centerl,widthl,highl,angle):
    heightl=10
    
    w=int(widthl/2*mt.cos(angle/180*mt.pi))
    h=int(widthl/2*mt.sin(angle/180*mt.pi))
    centerl=joitpoint-np.array([w,h])
    rect=(centerl, (widthl, heightl), angle)
    box = cv2.boxPoints(rect).astype(np.int0)
    cv2.drawContours(img,[box],0,(255,0,0),3)



for i in range(10):
    angle=i*20
    drawmotor(centerm,angle)
    drawlever(centerl,widthl,highl,angle)
    cv2.imshow("marm",img)
    cv2.waitKey(1000)
    #恢复背景
    img=imgcon.copy()

cv2.destroyAllWindows()
# Out:
# (1080, 1440, 3)
# 720 540
# (540, 720, 3)

# %%
import cv2
import numpy as np
import math  as mt

img=cv2.imread("marm.jpg")

#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
print(W,H)
img=cv2.resize(img,(W,H))
print(img.shape)

#电机模型
class mmotor():
    def __init__(self,center,angle,startangle):
        self.center=center
        self.angle=angle
        self.startangle=startangle
        
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        self.angle=angle
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)
    def drawrelative(self,relaangle):
        self.angle=self.startangle+relaangle
        self.draw(self.angle)

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.rightend=(width,0)
        self.rightendr=10
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            self.center=(self.jointpoint[0]-w,self.jointpoint[1]-h)
            self.rightend=(self.jointpoint[0]-w*2,self.jointpoint[1]-h*2)
        rect=(self.center, (self.width,self.height), self.angle)
        box = cv2.boxPoints(rect).astype(np.int0)        
        cv2.drawContours(img,[box],0,(255,0,0),3)          
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjointpoint(self,jointpoint):
        self.jointpoint=jointpoint
    def drawrightend(self):
        cv2.circle(img,self.rightend,self.rightendr,(0,0,255),3)

class Marm():
    def __init__(self,m01,m02,ml01,ml02):
        self.m01=m01
        self.m02=m02
        self.ml01=ml01
        self.ml02=ml02
        self.angle1=0
        self.angle2=0
        ml02.setjointpoint(m02.center)
    def draw(self,angle1,angle2):
        #电机02
        m02.drawrelative(angle2)
        #杆02
        ml02.setangle(angle2)
        ml02.draw()
        #电机01放在杆02的右端
        m01.setcenter(ml02.rightend)
        m01.startangle=180+m02.angle
        #电机01目前保持30度不变
        if angle1<=0:
            angle1=0
        m01.drawrelative(angle1)
        #杆01固定在电机01中心，角度与电机01一样
        ml01.setjointpoint(m01.center)
        ml01.setangle(m01.angle)
        ml01.draw()
        ml01.drawrightend()
        
m02=mmotor((260,360),0,0)
m01=mmotor((0,0),0,0)
ml01=mlever((0,0),340,20,0)
ml02=mlever((0,0),340,20,0)
marm=Marm(m01,m02,ml01,ml02)

for i in range(36):
    angle=i*5
    angle1=180-angle*2
    marm.draw(angle1,angle)
    cv2.imshow("marm",img)
    cv2.waitKey(500)
    #恢复背景
    img=imgcon.copy()

for i in range(36):
    angle=180-i*5
    angle1=45
    marm.draw(angle1,angle)
    cv2.imshow("marm",img)
    cv2.waitKey(500)
    #恢复背景
    img=imgcon.copy()

cv2.destroyAllWindows()
# Out:
# (1080, 1440, 3)
# 720 540
# (540, 720, 3)

# %%
import cv2
import numpy as np

img=cv2.imread("marm.jpg")
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
print(W,H)
img=cv2.resize(img,(W,H))
print(img.shape)

# 臂模型
center=(315,120)
width=400
angle=3
height=80
rect=(center, (width, height), angle)
box = cv2.boxPoints(rect).astype(np.int0)
cv2.drawContours(img,[box],0,(255,0,0),3)

center=(380,245)
width=340
angle=140
height=80
rect=(center, (width, height), angle)
box = cv2.boxPoints(rect).astype(np.int0)
cv2.drawContours(img,[box],0,(255,0,0),3)

cv2.imshow("marm",img)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# (1080, 1440, 3)
# 720 540
# (540, 720, 3)

# %%
import cv2
import numpy as np
import math  as mt

img=cv2.imread("marm.jpg")

#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
print(W,H)
img=cv2.resize(img,(W,H))
print(img.shape)

#电机模型
class mmotor():
    def __init__(self,center,angle,startangle):
        self.center=center
        self.angle=angle
        self.startangle=startangle
        
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        self.angle=angle
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)
    def drawrelative(self,relaangle):
        self.angle=self.startangle+relaangle
        self.draw(self.angle)

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.rightend=(width,0)
        self.rightendr=10
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            self.center=(self.jointpoint[0]-w,self.jointpoint[1]-h)
            self.rightend=(self.jointpoint[0]-w*2,self.jointpoint[1]-h*2)
        rect=(self.center, (self.width,self.height), self.angle)
        box = cv2.boxPoints(rect).astype(np.int0)        
        cv2.drawContours(img,[box],0,(255,0,0),3)          
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjointpoint(self,jointpoint):
        self.jointpoint=jointpoint
    def drawrightend(self):
        cv2.circle(img,self.rightend,self.rightendr,(0,0,255),3)
        

m01=mmotor((500,140),0,0)
ml01=mlever((0,0),340,20,0)
ml01.setjointpoint((460,260))
m02=mmotor((260,360),0,0)
ml02=mlever((0,0),340,20,0)
ml02.setjointpoint((260,360))

for i in range(18):
    angle=i*10
    #电机02
    m02.drawrelative(angle)
    #杆02
    ml02.setangle(angle)
    ml02.draw()
    #电机01放在杆02的右端
    m01.setcenter(ml02.rightend)
    m01.startangle=180+m02.angle
    #电机01目前保持30度不变
    m01.drawrelative(30)
    #杆01固定在电机01中心，角度与电机01一样
    ml01.setjointpoint(m01.center)
    ml01.setangle(m01.angle)
    ml01.draw()
    ml01.drawrightend()
    cv2.imshow("marm",img)
    cv2.waitKey(1000)
    #恢复背景
    img=imgcon.copy()

cv2.destroyAllWindows()
# Out:
# (1080, 1440, 3)
# 720 540
# (540, 720, 3)

# %%
import cv2
import numpy as np
import math  as mt

img=cv2.imread("marm.jpg")

#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
print(W,H)
img=cv2.resize(img,(W,H))
imgcon=img.copy()
print(img.shape)

#电机模型
class mmotor():
    def __init__(self,center,angle,startangle):
        self.center=center
        self.angle=angle
        self.startangle=startangle
        
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        self.angle=angle
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)
    def drawrelative(self,relaangle):
        self.angle=self.startangle+relaangle
        self.draw(self.angle)

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.rightend=(340,0)
        self.rightendr=10
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            self.center=(self.jointpoint[0]-w,self.jointpoint[1]-h)
            self.rightend=(self.jointpoint[0]-w*2,self.jointpoint[1]-h*2)
        rect=(self.center, (self.width,self.height), self.angle)
        box = cv2.boxPoints(rect).astype(np.int0)        
        cv2.drawContours(img,[box],0,(255,0,0),3)          
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjointpoint(self,jointpoint):
        self.jointpoint=jointpoint
    def drawrightend(self):
        cv2.circle(img,self.rightend,self.rightendr,(255,0,0),-1)
        

m01=mmotor((500,140),0,0)
ml01=mlever((0,0),340,20,0)
ml01.setjointpoint((460,260))
m02=mmotor((260,360),0,0)
ml02=mlever((0,0),340,20,0)
ml02.setjointpoint((260,360))

for i in range(10):
    angle=i*10
    #电机02
    m02.drawrelative(angle)
    #杆02
    ml02.setangle(angle)
    ml02.draw()
    #电机01放在杆02的右端
    m01.setcenter(ml02.rightend)
    print(ml02.rightend)
    #m01.startangle=180+m02.angle
    #电机01目前保持30度不变
    m01.drawrelative(30)
    #杆01固定在电机01中心，角度与电机01一样
    #ml01.setjointpoint(m01.center)
    #ml01.setangle(m01.angle)
    #ml01.draw()
    #ml01.drawrightend()
    cv2.imshow("marm",img)
    cv2.waitKey(1000)
    #恢复背景
    img=imgcon.copy()

cv2.destroyAllWindows()
# Out:
# (1080, 1440, 3)
# 720 540
# (540, 720, 3)
# (-80, 360)
# (-74, 302)
# (-58, 244)
# (-34, 192)
# (0, 142)
# (42, 100)
# (90, 66)
# (144, 42)
# (202, 26)
# (260, 20)

# %%
import cv2
import numpy as np
import math  as mt

img=cv2.imread("marm.jpg")
#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
print(W,H)
img=cv2.resize(img,(W,H))
imgcon=img.copy()
print(img.shape)

centerm2=(260,360)
centerm1=(500,140)
#电机
def drawmotor(centerm,angle):
    color=(0,255,0)
    r=30
    cv2.circle(img,centerm,r,color,5)
    rect=(centerm,(2*r,4),angle)
    box = cv2.boxPoints(rect).astype(np.int0)
    cv2.drawContours(img,[box],0,(255,0,0),3)

joitpoint=(260,360)
centerl=(0,0)
widthl=340
highl=20

# 臂长中心点，长度，角度
def drawlever(center,widthl,highl,angle):
    heightl=10
    
    w=int(widthl/2*mt.cos(angle/180*mt.pi))
    h=int(widthl/2*mt.sin(angle/180*mt.pi))
    center=joitpoint-np.array([w,h])
    rect=(center, (widthl, heightl), angle)
    box = cv2.boxPoints(rect).astype(np.int0)
    cv2.drawContours(img,[box],0,(255,0,0),3)


#电机01的位置变化
mc1=[(-80,360),(-74,302),(-58,244),(-34,192),(0,142),(42,100),(90,66),(144,42),(202,26),(260,20)]

for i in range(10):
    angle=i*10
    #电机02
    drawmotor(centerm2,angle)
    drawlever(centerl,widthl,highl,angle)    
    drawmotor(mc1[i],angle)
    cv2.imshow("marm",img)
    cv2.waitKey(1000)
    #恢复背景
    img=imgcon.copy()

cv2.destroyAllWindows()
